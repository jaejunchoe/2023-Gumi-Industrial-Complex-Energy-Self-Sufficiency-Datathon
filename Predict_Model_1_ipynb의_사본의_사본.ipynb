# %% [markdown]
# <a href="https://colab.research.google.com/github/jaejunchoe/2023-Gumi-Industrial-Complex-Energy-Self-Sufficiency-Datathon/blob/main/Predict_Model_1_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
excel_file_path_4 = '/content/cluster_4_data.xlsx'
excel_file_path_5 = '/content/cluster_5_data.xlsx'
excel_file_path_6 = '/content/cluster_6_data.xlsx'
excel_file_path_7 = '/content/cluster_7_data.xlsx'
excel_file_path_8 = '/content/cluster_8_data.xlsx'
excel_file_path_9 = '/content/cluster_9_data.xlsx'
excel_file_path_10 = '/content/cluster_10_data.xlsx'

# %%
# 엑셀 파일 경로 설정
excel_file_path_1 = '/content/cluster_1_data.xlsx'  # 파일 경로와 파일 이름에 맞게 수정
excel_file_path_2 = '/content/cluster_2_data.xlsx'
excel_file_path_3 = '/content/cluster_3_data.xlsx'
excel_file_path_4 = '/content/cluster_4_data.xlsx'
excel_file_path_5 = '/content/cluster_5_data.xlsx'
excel_file_path_6 = '/content/cluster_6_data.xlsx'
excel_file_path_7 = '/content/cluster_7_data.xlsx'
excel_file_path_8 = '/content/cluster_8_data.xlsx'
excel_file_path_9 = '/content/cluster_9_data.xlsx'
excel_file_path_10 = '/content/cluster_10_data.xlsx'

# %%
df_4 = pd.read_excel(excel_file_path_4)
df_5 = pd.read_excel(excel_file_path_5)
df_6 = pd.read_excel(excel_file_path_6)
df_7 = pd.read_excel(excel_file_path_7)
df_8 = pd.read_excel(excel_file_path_8)
df_9 = pd.read_excel(excel_file_path_9)
df_10 = pd.read_excel(excel_file_path_10)

# %%
# 엑셀 파일 불러오기
df_1 = pd.read_excel(excel_file_path_1)
df_2 = pd.read_excel(excel_file_path_2)
df_3 = pd.read_excel(excel_file_path_3)
df_4 = pd.read_excel(excel_file_path_4)
df_5 = pd.read_excel(excel_file_path_5)
df_6 = pd.read_excel(excel_file_path_6)
df_7 = pd.read_excel(excel_file_path_7)
df_8 = pd.read_excel(excel_file_path_8)
df_9 = pd.read_excel(excel_file_path_9)
df_10 = pd.read_excel(excel_file_path_10)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
from sklearn.ensemble import RandomForestRegressor, StackingRegressor, VotingRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from keras.src.engine.sequential import input_layer
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, ElasticNet
import lightgbm as lgb
from sklearn.svm import SVR
import joblib
from sklearn.cluster import KMeans

# %% [markdown]
# # 데이터 프레임 재구성

# %%
# 데이터 프레임 재구성
new_data_1 = []

for index, row in df_1.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_1.append(new_row)

new_df_1 = pd.DataFrame(new_data_1)

new_data_2 = []

for index, row in df_2.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_2.append(new_row)

new_df_2 = pd.DataFrame(new_data_2)

new_data_3 = []

for index, row in df_3.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_3.append(new_row)

new_df_3 = pd.DataFrame(new_data_3)

new_data_4 = []

for index, row in df_4.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_4.append(new_row)

new_df_4 = pd.DataFrame(new_data_4)

new_data_5 = []

for index, row in df_5.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_5.append(new_row)

new_df_5 = pd.DataFrame(new_data_5)

new_data_6 = []

for index, row in df_6.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_6.append(new_row)

new_df_6 = pd.DataFrame(new_data_6)

new_data_7 = []

for index, row in df_7.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_7.append(new_row)

new_df_7 = pd.DataFrame(new_data_7)

new_data_8 = []

for index, row in df_8.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_8.append(new_row)

new_df_8 = pd.DataFrame(new_data_8)

new_data_9 = []

for index, row in df_9.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_9.append(new_row)

new_df_9 = pd.DataFrame(new_data_9)

new_data_10 = []

for index, row in df_10.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_10.append(new_row)

new_df_10 = pd.DataFrame(new_data_10)

# %%
new_data_4 = []

for index, row in df_4.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_4.append(new_row)

new_df_4 = pd.DataFrame(new_data_4)

new_data_5 = []

for index, row in df_5.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_5.append(new_row)

new_df_5 = pd.DataFrame(new_data_5)

new_data_6 = []

for index, row in df_6.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_6.append(new_row)

new_df_6 = pd.DataFrame(new_data_6)

new_data_7 = []

for index, row in df_7.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_7.append(new_row)

new_df_7 = pd.DataFrame(new_data_7)

new_data_8 = []

for index, row in df_8.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_8.append(new_row)

new_df_8 = pd.DataFrame(new_data_8)

new_data_9 = []

for index, row in df_9.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_9.append(new_row)

new_df_9 = pd.DataFrame(new_data_9)

new_data_10 = []

for index, row in df_10.iterrows():
    for hour in range(1, 25):
        new_row = {
            '계약번호': row['계약번호'],
            '날짜': row['날짜'],
            '시간': f"{hour}시",
            '전력량': row[f'{hour}시']
        }
        new_data_10.append(new_row)

new_df_10 = pd.DataFrame(new_data_10)

# %%
print(new_df_1.info(), '\n')
print(new_df_2.info(), '\n')
print(new_df_3.info(), '\n')
print(new_df_4.info(), '\n')
print(new_df_5.info(), '\n')
print(new_df_6.info(), '\n')
print(new_df_7.info(), '\n')
print(new_df_8.info(), '\n')
print(new_df_9.info(), '\n')
print(new_df_10.info(), '\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384192 entries, 0 to 384191
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   계약번호    384192 non-null  object
#  1   날짜      384192 non-null  datetime64[ns]
#  2   시간      384192 non-null  object
#  3   전력량     384192 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 11.7+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962288 entries, 0 to 1962287
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   계약번호    object
#  1   날짜      datetime64[ns]
#  2   시간      object
#  3   전력량     float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 59.9+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283776 entries, 0 to 283775
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
# ...

# %%
print(new_df_1.info(), '\n')
print(new_df_2.info(), '\n')
print(new_df_3.info(), '\n')
print(new_df_4.info(), '\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384192 entries, 0 to 384191
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   계약번호    384192 non-null  object
#  1   날짜      384192 non-null  datetime64[ns]
#  2   시간      384192 non-null  object
#  3   전력량     384192 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 11.7+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962288 entries, 0 to 1962287
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   계약번호    object
#  1   날짜      datetime64[ns]
#  2   시간      object
#  3   전력량     float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 59.9+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283776 entries, 0 to 283775
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
# ...

# %% [markdown]
# # 자기상관계수

# %%
print('1번째 클러스터')
for i in range(1, 10):
    print(i, new_df_1['전력량'].autocorr(i))

print('2번째 클러스터')
for i in range(1, 10):
    print(i, new_df_2['전력량'].autocorr(i))

print('3번째 클러스터')
for i in range(1, 10):
    print(i, new_df_3['전력량'].autocorr(i))

print('4번째 클러스터')
for i in range(1, 10):
    print(i, new_df_4['전력량'].autocorr(i))

print('5번째 클러스터')
for i in range(1, 10):
    print(i, new_df_5['전력량'].autocorr(i))

print('6번째 클러스터')
for i in range(1, 10):
    print(i, new_df_6['전력량'].autocorr(i))

print('7번째 클러스터')
for i in range(1, 10):
    print(i, new_df_7['전력량'].autocorr(i))

print('8번째 클러스터')
for i in range(1, 10):
    print(i, new_df_8['전력량'].autocorr(i))

print('9번째 클러스터')
for i in range(1, 10):
    print(i, new_df_9['전력량'].autocorr(i))

print('10번째 클러스터')
for i in range(1, 10):
    print(i, new_df_10['전력량'].autocorr(i))
# Out:
# 1번째 클러스터
# 1 0.9539038964221928
# 2 0.9221651305754268
# 3 0.8906717268695088
# 4 0.8593075153675498
# 5 0.829445589087368
# 6 0.8001726542697745
# 7 0.7696080757916471
# 8 0.742608353523555
# 9 0.7182896826571222
# 2번째 클러스터
# 1 0.9477624501929254
# 2 0.9017493901944372
# 3 0.8557030268754421
# 4 0.8130716206758594
# 5 0.7767144465332859
# 6 0.736468133554324
# 7 0.6946528287548485
# 8 0.6523801864216525
# 9 0.6157345022179065
# 3번째 클러스터
# 1 0.9433670783312975
# 2 0.9009529606010271
# 3 0.8590735828998165
# 4 0.8171426621570808
# 5 0.7786300582583455
# 6 0.737580912958989
# 7 0.6957473831541887
# 8 0.656348749190213
# 9 0.6169741477145518
# 4번째 클러스터
# 1 0.9075488640598821
# 2 0.7917816686716077
# 3 0.6810759441009565
# 4 0.5839448928735026
# 5 0.5011110152222819
# 6 0.41235283555892704
# 7 0.3202211313042937
# 8 0.23101145767764494
# 9 0.14889483448929483
# 5번째 클러스터
# 1 0.9412583985328977
# 2 0.8852021954728925
# 3 0.8311327121063828
# 4 0.7778369267904555
# 5 0.7330674036080753
# ...

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Cluster 1_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_1['전력량'])
plt.title('Cluster 1 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 2_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_2['전력량'])
plt.title('Cluster 2 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 3_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_3['전력량'])
plt.title('Cluster 3 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 4_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_4['전력량'])
plt.title('Cluster 4 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 5_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_5['전력량'])
plt.title('Cluster 5 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 6_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_data_6df_6['전력량'])
plt.title('Cluster 6 Autocorrelation Graph (ACF) Plot')
plt.show()


# Cluster 7_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_7['전력량'])
plt.title('Cluster 7 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 8_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_8['전력량'])
plt.title('Cluster 8 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 9_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_9['전력량'])
plt.title('Cluster 9 Autocorrelation Graph (ACF) Plot')
plt.show()



# Cluster 10_자기상관계수 그래프 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_10['전력량'])
plt.title('Cluster 10 Autocorrelation Graph (ACF) Plot')
plt.show()

# %%
# 자기상관함수 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_4['전력량'])
plt.title('Cluster 4 Autocorrelation Graph (ACF) Plot')
plt.show()



# 자기상관함수 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_5['전력량'])
plt.title('Cluster 5 Autocorrelation Graph (ACF) Plot')
plt.show()



# 자기상관함수 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_6['전력량'])
plt.title('Cluster 6 Autocorrelation Graph (ACF) Plot')
plt.show()


# 자기상관함수 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_7['전력량'])
plt.title('Cluster 7 Autocorrelation Graph (ACF) Plot')
plt.show()



# 자기상관함수 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_8['전력량'])
plt.title('Cluster 8 Autocorrelation Graph (ACF) Plot')
plt.show()



# 자기상관함수 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_9['전력량'])
plt.title('Cluster 9 Autocorrelation Graph (ACF) Plot')
plt.show()



# 자기상관함수 (ACF)
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(new_df_10['전력량'])
plt.title('Cluster 10 Autocorrelation Graph (ACF) Plot')
plt.show()

# %%
print('1번째 클러스터')
for i in range(1, 10):
    print(i, new_df_1['전력량'].autocorr(i))

print('2번째 클러스터')
for i in range(1, 10):
    print(i, new_df_2['전력량'].autocorr(i))

print('3번째 클러스터')
for i in range(1, 10):
    print(i, new_df_3['전력량'].autocorr(i))

print('4번째 클러스터')
for i in range(1, 10):
    print(i, new_df_4['전력량'].autocorr(i))
# Out:
# 1번째 클러스터
# 1 0.9539038964221928
# 2 0.9221651305754268
# 3 0.8906717268695088
# 4 0.8593075153675498
# 5 0.829445589087368
# 6 0.8001726542697745
# 7 0.7696080757916471
# 8 0.742608353523555
# 9 0.7182896826571222
# 2번째 클러스터
# 1 0.9477624501929254
# 2 0.9017493901944372
# 3 0.8557030268754421
# 4 0.8130716206758594
# 5 0.7767144465332859
# 6 0.736468133554324
# 7 0.6946528287548485
# 8 0.6523801864216525
# 9 0.6157345022179065
# 3번째 클러스터
# 1 0.9433670783312975
# 2 0.9009529606010271
# 3 0.8590735828998165
# 4 0.8171426621570808
# 5 0.7786300582583455
# 6 0.737580912958989
# 7 0.6957473831541887
# 8 0.656348749190213
# 9 0.6169741477145518
# 4번째 클러스터
# 1 0.9075488640598821
# 2 0.7917816686716077
# 3 0.6810759441009565
# 4 0.5839448928735026
# 5 0.5011110152222819
# 6 0.41235283555892704
# 7 0.3202211313042937
# 8 0.23101145767764494
# 9 0.14889483448929483

# %% [markdown]
# # lang 추가

# %%
new_df_1.loc[:,'lag1'] = new_df_1['전력량'].shift(1)
new_df_1.loc[:,'lag2'] = new_df_1['전력량'].shift(2)
new_df_1.loc[:,'lag3'] = new_df_1['전력량'].shift(3)
new_df_1.loc[:,'lag4'] = new_df_1['전력량'].shift(4)

new_df_2.loc[:,'lag1'] = new_df_2['전력량'].shift(1)
new_df_2.loc[:,'lag2'] = new_df_2['전력량'].shift(2)
new_df_2.loc[:,'lag3'] = new_df_2['전력량'].shift(3)
new_df_2.loc[:,'lag4'] = new_df_2['전력량'].shift(4)

new_df_3.loc[:,'lag1'] = new_df_3['전력량'].shift(1)
new_df_3.loc[:,'lag2'] = new_df_3['전력량'].shift(2)
new_df_3.loc[:,'lag3'] = new_df_3['전력량'].shift(3)
new_df_3.loc[:,'lag4'] = new_df_3['전력량'].shift(4)

new_df_4.loc[:,'lag1'] = new_df_4['전력량'].shift(1)
new_df_4.loc[:,'lag2'] = new_df_4['전력량'].shift(2)
new_df_4.loc[:,'lag3'] = new_df_4['전력량'].shift(3)
new_df_4.loc[:,'lag4'] = new_df_4['전력량'].shift(4)

new_df_5.loc[:,'lag1'] = new_df_5['전력량'].shift(1)
new_df_5.loc[:,'lag2'] = new_df_5['전력량'].shift(2)
new_df_5.loc[:,'lag3'] = new_df_5['전력량'].shift(3)
new_df_5.loc[:,'lag4'] = new_df_5['전력량'].shift(4)

new_df_6.loc[:,'lag1'] = new_df_6['전력량'].shift(1)
new_df_6.loc[:,'lag2'] = new_df_6['전력량'].shift(2)
new_df_6.loc[:,'lag3'] = new_df_6['전력량'].shift(3)
new_df_6.loc[:,'lag4'] = new_df_6['전력량'].shift(4)

new_df_7.loc[:,'lag1'] = new_df_7['전력량'].shift(1)
new_df_7.loc[:,'lag2'] = new_df_7['전력량'].shift(2)
new_df_7.loc[:,'lag3'] = new_df_7['전력량'].shift(3)
new_df_7.loc[:,'lag4'] = new_df_7['전력량'].shift(4)

new_df_8.loc[:,'lag1'] = new_df_8['전력량'].shift(1)
new_df_8.loc[:,'lag2'] = new_df_8['전력량'].shift(2)
new_df_8.loc[:,'lag3'] = new_df_8['전력량'].shift(3)
new_df_8.loc[:,'lag4'] = new_df_8['전력량'].shift(4)

new_df_9.loc[:,'lag1'] = new_df_9['전력량'].shift(1)
new_df_9.loc[:,'lag2'] = new_df_9['전력량'].shift(2)
new_df_9.loc[:,'lag3'] = new_df_9['전력량'].shift(3)
new_df_9.loc[:,'lag4'] = new_df_9['전력량'].shift(4)

new_df_10.loc[:,'lag1'] = new_df_10['전력량'].shift(1)
new_df_10.loc[:,'lag2'] = new_df_10['전력량'].shift(2)
new_df_10.loc[:,'lag3'] = new_df_10['전력량'].shift(3)
new_df_10.loc[:,'lag4'] = new_df_10['전력량'].shift(4)

# %%
new_df_1.loc[:,'lag1'] = new_df_1['전력량'].shift(1)
new_df_1.loc[:,'lag2'] = new_df_1['전력량'].shift(2)
new_df_1.loc[:,'lag3'] = new_df_1['전력량'].shift(3)
new_df_1.loc[:,'lag4'] = new_df_1['전력량'].shift(4)

new_df_2.loc[:,'lag1'] = new_df_2['전력량'].shift(1)
new_df_2.loc[:,'lag2'] = new_df_2['전력량'].shift(2)
new_df_2.loc[:,'lag3'] = new_df_2['전력량'].shift(3)
new_df_2.loc[:,'lag4'] = new_df_2['전력량'].shift(4)

new_df_3.loc[:,'lag1'] = new_df_3['전력량'].shift(1)
new_df_3.loc[:,'lag2'] = new_df_3['전력량'].shift(2)
new_df_3.loc[:,'lag3'] = new_df_3['전력량'].shift(3)
new_df_3.loc[:,'lag4'] = new_df_3['전력량'].shift(4)

new_df_4.loc[:,'lag1'] = new_df_4['전력량'].shift(1)
new_df_4.loc[:,'lag2'] = new_df_4['전력량'].shift(2)
new_df_4.loc[:,'lag3'] = new_df_4['전력량'].shift(3)
new_df_4.loc[:,'lag4'] = new_df_4['전력량'].shift(4)

# %%
new_df_1 = new_df_1.drop(['계약번호', '날짜'], axis=1)
new_df_2 = new_df_2.drop(['계약번호', '날짜'], axis=1)
new_df_3 = new_df_3.drop(['계약번호', '날짜'], axis=1)
new_df_4 = new_df_4.drop(['계약번호', '날짜'], axis=1)
new_df_5 = new_df_5.drop(['계약번호', '날짜'], axis=1)
new_df_6 = new_df_6.drop(['계약번호', '날짜'], axis=1)
new_df_7 = new_df_7.drop(['계약번호', '날짜'], axis=1)
new_df_8 = new_df_8.drop(['계약번호', '날짜'], axis=1)
new_df_9 = new_df_9.drop(['계약번호', '날짜'], axis=1)
new_df_10 = new_df_10.drop(['계약번호', '날짜'], axis=1)

# %%
new_df_1 = new_df_1.drop(['계약번호', '날짜'], axis=1)
new_df_2 = new_df_2.drop(['계약번호', '날짜'], axis=1)
new_df_3 = new_df_3.drop(['계약번호', '날짜'], axis=1)
new_df_4 = new_df_4.drop(['계약번호', '날짜'], axis=1)

# %%
print(new_df_1.info())
print(new_df_2.info())
print(new_df_3.info())
print(new_df_4.info())
print(new_df_5.info())
print(new_df_6.info())
print(new_df_7.info())
print(new_df_8.info())
print(new_df_9.info())
print(new_df_10.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384188 entries, 0 to 384187
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   시간      384188 non-null  object
#  1   전력량     384188 non-null  float64
#  2   lag1    384188 non-null  float64
#  3   lag2    384188 non-null  float64
#  4   lag3    384188 non-null  float64
#  5   lag4    384188 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 17.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962284 entries, 0 to 1962283
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   시간      object
#  1   전력량     float64
#  2   lag1    float64
#  3   lag2    float64
#  4   lag3    float64
#  5   lag4    float64
# dtypes: float64(5), object(1)
# memory usage: 89.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283772 entries, 0 to 283771
# Data columns (total 6 columns):
# ...

# %%
# 시간 열에서 '시'를 제거하고 숫자만 남기기
new_df_1['시간'] = new_df_1['시간'].str.replace('시', '')
new_df_2['시간'] = new_df_2['시간'].str.replace('시', '')
new_df_3['시간'] = new_df_3['시간'].str.replace('시', '')
new_df_4['시간'] = new_df_4['시간'].str.replace('시', '')
new_df_5['시간'] = new_df_5['시간'].str.replace('시', '')
new_df_6['시간'] = new_df_6['시간'].str.replace('시', '')
new_df_7['시간'] = new_df_7['시간'].str.replace('시', '')
new_df_8['시간'] = new_df_8['시간'].str.replace('시', '')
new_df_9['시간'] = new_df_9['시간'].str.replace('시', '')
new_df_10['시간'] = new_df_10['시간'].str.replace('시', '')

# %%
# 시간 열에서 '시'를 제거하고 숫자만 남기기
new_df_1['시간'] = new_df_1['시간'].str.replace('시', '')
new_df_2['시간'] = new_df_2['시간'].str.replace('시', '')
new_df_3['시간'] = new_df_3['시간'].str.replace('시', '')
new_df_4['시간'] = new_df_4['시간'].str.replace('시', '')

# %%
new_df_1 = new_df_1.dropna()
new_df_2 = new_df_2.dropna()
new_df_3 = new_df_3.dropna()
new_df_4 = new_df_4.dropna()
new_df_5 = new_df_5.dropna()
new_df_6 = new_df_6.dropna()
new_df_7 = new_df_7.dropna()
new_df_8 = new_df_8.dropna()
new_df_9 = new_df_9.dropna()
new_df_10 = new_df_10.dropna()

new_df_1 = new_df_1.reset_index(drop=True)
new_df_2 = new_df_2.reset_index(drop=True)
new_df_3 = new_df_3.reset_index(drop=True)
new_df_4 = new_df_4.reset_index(drop=True)
new_df_5 = new_df_5.reset_index(drop=True)
new_df_6 = new_df_6.reset_index(drop=True)
new_df_7 = new_df_7.reset_index(drop=True)
new_df_8 = new_df_8.reset_index(drop=True)
new_df_9 = new_df_9.reset_index(drop=True)
new_df_10 = new_df_10.reset_index(drop=True)

# %%
new_df_1 = new_df_1.dropna()
new_df_2 = new_df_2.dropna()
new_df_3 = new_df_3.dropna()
new_df_4 = new_df_4.dropna()

new_df_1 = new_df_1.reset_index(drop=True)
new_df_2 = new_df_2.reset_index(drop=True)
new_df_3 = new_df_3.reset_index(drop=True)
new_df_4 = new_df_4.reset_index(drop=True)

y_cluster1 = new_df_1['전력량']
x_cluster1 = new_df_1.drop(['전력량'], axis=1)

y_cluster2 = new_df_2['전력량']
x_cluster2 = new_df_2.drop(['전력량'], axis=1)

y_cluster3 = new_df_3['전력량']
x_cluster3 = new_df_3.drop(['전력량'], axis=1)

y_cluster4 = new_df_4['전력량']
x_cluster4 = new_df_4.drop(['전력량'], axis=1)

# %%
y_cluster1 = new_df_1['전력량']
x_cluster1 = new_df_1.drop(['전력량'], axis=1)

y_cluster2 = new_df_2['전력량']
x_cluster2 = new_df_2.drop(['전력량'], axis=1)

y_cluster3 = new_df_3['전력량']
x_cluster3 = new_df_3.drop(['전력량'], axis=1)

y_cluster4 = new_df_4['전력량']
x_cluster4 = new_df_4.drop(['전력량'], axis=1)

y_cluster5 = new_df_5['전력량']
x_cluster5 = new_df_5.drop(['전력량'], axis=1)

y_cluster6 = new_df_6['전력량']
x_cluster6 = new_df_6.drop(['전력량'], axis=1)

y_cluster7 = new_df_7['전력량']
x_cluster7 = new_df_7.drop(['전력량'], axis=1)

y_cluster8 = new_df_8['전력량']
x_cluster8 = new_df_8.drop(['전력량'], axis=1)

y_cluster9 = new_df_9['전력량']
x_cluster9 = new_df_9.drop(['전력량'], axis=1)

y_cluster10 = new_df_10['전력량']
x_cluster10 = new_df_10.drop(['전력량'], axis=1)

# %% [markdown]
# # train & test set and scaler

# %%
x_cluster1_train, x_cluster1_test, y_cluster1_train, y_cluster1_test = train_test_split(
    x_cluster1, y_cluster1, test_size=0.2, random_state=42)

x_cluster2_train, x_cluster2_test, y_cluster2_train, y_cluster2_test = train_test_split(
    x_cluster2, y_cluster2, test_size=0.2, random_state=42)

x_cluster3_train, x_cluster3_test, y_cluster3_train, y_cluster3_test = train_test_split(
    x_cluster3, y_cluster3, test_size=0.2, random_state=42)

x_cluster4_train, x_cluster4_test, y_cluster4_train, y_cluster4_test = train_test_split(
    x_cluster4, y_cluster4, test_size=0.2, random_state=42)

x_cluster5_train, x_cluster5_test, y_cluster5_train, y_cluster5_test = train_test_split(
    x_cluster5, y_cluster5, test_size=0.2, random_state=42)

x_cluster6_train, x_cluster6_test, y_cluster6_train, y_cluster6_test = train_test_split(
    x_cluster6, y_cluster6, test_size=0.2, random_state=42)

x_cluster7_train, x_cluster7_test, y_cluster7_train, y_cluster7_test = train_test_split(
    x_cluster7, y_cluster7, test_size=0.2, random_state=42)

x_cluster8_train, x_cluster8_test, y_cluster8_train, y_cluster8_test = train_test_split(
    x_cluster8, y_cluster8, test_size=0.2, random_state=42)

x_cluster9_train, x_cluster9_test, y_cluster9_train, y_cluster9_test = train_test_split(
    x_cluster9, y_cluster9, test_size=0.2, random_state=42)

x_cluster10_train, x_cluster10_test, y_cluster10_train, y_cluster10_test = train_test_split(
    x_cluster10, y_cluster10, test_size=0.2, random_state=42)

# %%
x_cluster1_train, x_cluster1_test, y_cluster1_train, y_cluster1_test = train_test_split(
    x_cluster1, y_cluster1, test_size=0.2, random_state=42)

x_cluster2_train, x_cluster2_test, y_cluster2_train, y_cluster2_test = train_test_split(
    x_cluster2, y_cluster2, test_size=0.2, random_state=42)

x_cluster3_train, x_cluster3_test, y_cluster3_train, y_cluster3_test = train_test_split(
    x_cluster3, y_cluster3, test_size=0.2, random_state=42)

x_cluster4_train, x_cluster4_test, y_cluster4_train, y_cluster4_test = train_test_split(
    x_cluster4, y_cluster4, test_size=0.2, random_state=42)

scaler1 = StandardScaler()
scaler2 = StandardScaler()
scaler3 = StandardScaler()
scaler4 = StandardScaler()

scaler1.fit(x_cluster1_train)
scaler2.fit(x_cluster2_train)
scaler3.fit(x_cluster3_train)
scaler4.fit(x_cluster4_train)

x_cluster1_train = scaler1.transform(x_cluster1_train)
x_cluster1_test = scaler1.transform(x_cluster1_test)

x_cluster2_train = scaler2.transform(x_cluster2_train)
x_cluster2_test = scaler2.transform(x_cluster2_test)

x_cluster3_train = scaler3.transform(x_cluster3_train)
x_cluster3_test = scaler3.transform(x_cluster3_test)

x_cluster4_train = scaler4.transform(x_cluster4_train)
x_cluster4_test = scaler4.transform(x_cluster4_test)

x_ff1_train = x_cluster1_train
y_ff1_train = y_cluster1_train

x_ff2_train = x_cluster2_train
y_ff2_train = y_cluster2_train

x_ff3_train = x_cluster3_train
y_ff3_train = y_cluster3_train

x_ff4_train = x_cluster4_train
y_ff4_train = y_cluster4_train

# %%
scaler1 = StandardScaler()
scaler2 = StandardScaler()
scaler3 = StandardScaler()
scaler4 = StandardScaler()
scaler5 = StandardScaler()
scaler6 = StandardScaler()
scaler7 = StandardScaler()
scaler8 = StandardScaler()
scaler9 = StandardScaler()
scaler10 = StandardScaler()

# %%
scaler1.fit(x_cluster1_train)
scaler2.fit(x_cluster2_train)
scaler3.fit(x_cluster3_train)
scaler4.fit(x_cluster4_train)
scaler5.fit(x_cluster5_train)
scaler6.fit(x_cluster6_train)
scaler7.fit(x_cluster7_train)
scaler8.fit(x_cluster8_train)
scaler9.fit(x_cluster9_train)
scaler10.fit(x_cluster10_train)
# Out:
# StandardScaler()

# %%
x_cluster1_train = scaler1.transform(x_cluster1_train)
x_cluster1_test = scaler1.transform(x_cluster1_test)

x_cluster2_train = scaler2.transform(x_cluster2_train)
x_cluster2_test = scaler2.transform(x_cluster2_test)

x_cluster3_train = scaler3.transform(x_cluster3_train)
x_cluster3_test = scaler3.transform(x_cluster3_test)

x_cluster4_train = scaler4.transform(x_cluster4_train)
x_cluster4_test = scaler4.transform(x_cluster4_test)

x_cluster5_train = scaler5.transform(x_cluster5_train)
x_cluster5_test = scaler5.transform(x_cluster5_test)

x_cluster6_train = scaler6.transform(x_cluster6_train)
x_cluster6_test = scaler6.transform(x_cluster6_test)

x_cluster7_train = scaler7.transform(x_cluster7_train)
x_cluster7_test = scaler7.transform(x_cluster7_test)

x_cluster8_train = scaler8.transform(x_cluster8_train)
x_cluster8_test = scaler8.transform(x_cluster8_test)

x_cluster9_train = scaler9.transform(x_cluster9_train)
x_cluster9_test = scaler9.transform(x_cluster9_test)

x_cluster10_train = scaler10.transform(x_cluster10_train)
x_cluster10_test = scaler10.transform(x_cluster10_test)

# %%
x_ff1_train = x_cluster1_train
y_ff1_train = y_cluster1_train

x_ff2_train = x_cluster2_train
y_ff2_train = y_cluster2_train

x_ff3_train = x_cluster3_train
y_ff3_train = y_cluster3_train

x_ff4_train = x_cluster4_train
y_ff4_train = y_cluster4_train

x_ff5_train = x_cluster5_train
y_ff5_train = y_cluster5_train

x_ff6_train = x_cluster6_train
y_ff6_train = y_cluster6_train

x_ff7_train = x_cluster7_train
y_ff7_train = y_cluster7_train

x_ff8_train = x_cluster8_train
y_ff8_train = y_cluster8_train

x_ff9_train = x_cluster9_train
y_ff9_train = y_cluster9_train

x_ff10_train = x_cluster10_train
y_ff10_train = y_cluster10_train

# %% [markdown]
# # KNN

# %%
# 1 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster1_train, y_cluster1_train)
  predict_knn1 = knn.predict(x_cluster1_test)
  r2_knn1 = r2_score(y_cluster1_test, predict_knn1)
  r2_scores[n] = r2_knn1

best_n_neighbors1 = max(r2_scores, key=r2_scores.get)
best_r2_score1 = r2_scores[best_n_neighbors1]

print(f"최적의 n_neighbors cluster 1: {best_n_neighbors1}")
print(f"최적의 R^2 cluster 1: {best_r2_score1}")

# 2 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster2_train, y_cluster2_train)
  predict_knn2 = knn.predict(x_cluster2_test)
  r2_knn2 = r2_score(y_cluster2_test, predict_knn2)
  r2_scores[n] = r2_knn2

best_n_neighbors2 = max(r2_scores, key=r2_scores.get)
best_r2_score2 = r2_scores[best_n_neighbors2]

print(f"최적의 n_neighbors cluster 2: {best_n_neighbors2}")
print(f"최적의 R^2 cluster 2: {best_r2_score2}")

# 3 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster3_train, y_cluster3_train)
  predict_knn3 = knn.predict(x_cluster3_test)
  r2_knn3 = r2_score(y_cluster3_test, predict_knn3)
  r2_scores[n] = r2_knn3

best_n_neighbors3 = max(r2_scores, key=r2_scores.get)
best_r2_score3 = r2_scores[best_n_neighbors3]

print(f"최적의 n_neighbors cluster 3: {best_n_neighbors3}")
print(f"최적의 R^2 cluster 3: {best_r2_score3}")

# 4 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster4_train, y_cluster4_train)
  predict_knn4 = knn.predict(x_cluster4_test)
  r2_knn4 = r2_score(y_cluster4_test, predict_knn4)
  r2_scores[n] = r2_knn4

best_n_neighbors4 = max(r2_scores, key=r2_scores.get)
best_r2_score4 = r2_scores[best_n_neighbors3]

print(f"최적의 n_neighbors cluster 4: {best_n_neighbors4}")
print(f"최적의 R^2 cluster 4: {best_r2_score4}")

# 5 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster5_train, y_cluster5_train)
  predict_knn5 = knn.predict(x_cluster5_test)
  r2_knn5 = r2_score(y_cluster5_test, predict_knn5)
  r2_scores[n] = r2_knn5

best_n_neighbors5 = max(r2_scores, key=r2_scores.get)
best_r2_score5 = r2_scores[best_n_neighbors5]

print(f"최적의 n_neighbors cluster 5: {best_n_neighbors5}")
print(f"최적의 R^2 cluster 5: {best_r2_score1}")

# 6 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster6_train, y_cluster6_train)
  predict_knn6 = knn.predict(x_cluster6_test)
  r2_knn6 = r2_score(y_cluster6_test, predict_knn6)
  r2_scores[n] = r2_knn6

best_n_neighbors6 = max(r2_scores, key=r2_scores.get)
best_r2_score6 = r2_scores[best_n_neighbors6]

print(f"최적의 n_neighbors cluster 6: {best_n_neighbors6}")
print(f"최적의 R^2 cluster 6: {best_r2_score6}")

# 7 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster7_train, y_cluster7_train)
  predict_knn7 = knn.predict(x_cluster7_test)
  r2_knn7 = r2_score(y_cluster7_test, predict_knn7)
  r2_scores[n] = r2_knn7

best_n_neighbors7 = max(r2_scores, key=r2_scores.get)
best_r2_score7 = r2_scores[best_n_neighbors7]

print(f"최적의 n_neighbors cluster 7: {best_n_neighbors7}")
print(f"최적의 R^2 cluster 7: {best_r2_score7}")

# 8 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster8_train, y_cluster8_train)
  predict_knn8 = knn.predict(x_cluster8_test)
  r2_knn8 = r2_score(y_cluster4_test, predict_knn8)
  r2_scores[n] = r2_knn8

best_n_neighbors8 = max(r2_scores, key=r2_scores.get)
best_r2_score8 = r2_scores[best_n_neighbors8]

print(f"최적의 n_neighbors cluster 8: {best_n_neighbors8}")
print(f"최적의 R^2 cluster 8: {best_r2_score8}")

# 9 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster9_train, y_cluster9_train)
  predict_knn9 = knn.predict(x_cluster9_test)
  r2_knn9 = r2_score(y_cluster9_test, predict_knn9)
  r2_scores[n] = r2_knn9

best_n_neighbors9 = max(r2_scores, key=r2_scores.get)
best_r2_score9 = r2_scores[best_n_neighbors9]

print(f"최적의 n_neighbors cluster 9: {best_n_neighbors9}")
print(f"최적의 R^2 cluster 9: {best_r2_score9}")

# 10 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster10_train, y_cluster10_train)
  predict_knn10 = knn.predict(x_cluster10_test)
  r2_knn10 = r2_score(y_cluster10_test, predict_knn10)
  r2_scores[n] = r2_knn10

best_n_neighbors10 = max(r2_scores, key=r2_scores.get)
best_r2_score10 = r2_scores[best_n_neighbors10]

print(f"최적의 n_neighbors cluster 10: {best_n_neighbors10}")
print(f"최적의 R^2 cluster 10: {best_r2_score10}")
# Out:
# 최적의 n_neighbors cluster 1: 17
# 최적의 R^2 cluster 1: 0.9302955640919239
# 최적의 n_neighbors cluster 2: 29
# 최적의 R^2 cluster 2: 0.92759016470913
# 최적의 n_neighbors cluster 3: 18
# 최적의 R^2 cluster 3: 0.9229304993942793
# 최적의 n_neighbors cluster 4: 12
# 최적의 R^2 cluster 4: 0.8648653901909941
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-6159717dfab6> in <cell line: 68>()
#      68 for n in range(2, 50):
#      69   knn = KNeighborsRegressor(n_neighbors=n)
# ---> 70   knn.fit(x_cluster5_train, y_cluster5_train)
#      71   predict_knn5 = knn.predict(x_cluster5_test)
#      72   r2_knn5 = r2_score(y_cluster5_test, predict_knn5)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py in fit(self, X, y)
#     215         self._validate_params()
#     216
# --> 217         return self._fit(X, y)
#     218
#     219     def predict(self, X):
#
# ...

# %%
# 5 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster5_train, y_cluster5_train)
  predict_knn5 = knn.predict(x_cluster5_test)
  r2_knn5 = r2_score(y_cluster5_test, predict_knn5)
  r2_scores[n] = r2_knn5

best_n_neighbors5 = max(r2_scores, key=r2_scores.get)
best_r2_score5 = r2_scores[best_n_neighbors5]

print(f"최적의 n_neighbors cluster 5: {best_n_neighbors5}")
print(f"최적의 R^2 cluster 5: {best_r2_score1}")

# 6 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster6_train, y_cluster6_train)
  predict_knn6 = knn.predict(x_cluster6_test)
  r2_knn6 = r2_score(y_cluster6_test, predict_knn6)
  r2_scores[n] = r2_knn6

best_n_neighbors6 = max(r2_scores, key=r2_scores.get)
best_r2_score6 = r2_scores[best_n_neighbors6]

print(f"최적의 n_neighbors cluster 6: {best_n_neighbors6}")
print(f"최적의 R^2 cluster 6: {best_r2_score6}")

# 7 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster7_train, y_cluster7_train)
  predict_knn7 = knn.predict(x_cluster7_test)
  r2_knn7 = r2_score(y_cluster7_test, predict_knn7)
  r2_scores[n] = r2_knn7

best_n_neighbors7 = max(r2_scores, key=r2_scores.get)
best_r2_score7 = r2_scores[best_n_neighbors7]

print(f"최적의 n_neighbors cluster 7: {best_n_neighbors7}")
print(f"최적의 R^2 cluster 7: {best_r2_score7}")

# 8 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster8_train, y_cluster8_train)
  predict_knn8 = knn.predict(x_cluster8_test)
  r2_knn8 = r2_score(y_cluster4_test, predict_knn8)
  r2_scores[n] = r2_knn8

best_n_neighbors8 = max(r2_scores, key=r2_scores.get)
best_r2_score8 = r2_scores[best_n_neighbors8]

print(f"최적의 n_neighbors cluster 8: {best_n_neighbors8}")
print(f"최적의 R^2 cluster 8: {best_r2_score8}")

# 9 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster9_train, y_cluster9_train)
  predict_knn9 = knn.predict(x_cluster9_test)
  r2_knn9 = r2_score(y_cluster9_test, predict_knn9)
  r2_scores[n] = r2_knn9

best_n_neighbors9 = max(r2_scores, key=r2_scores.get)
best_r2_score9 = r2_scores[best_n_neighbors9]

print(f"최적의 n_neighbors cluster 9: {best_n_neighbors9}")
print(f"최적의 R^2 cluster 9: {best_r2_score9}")

# 10 cluster
r2_scores = {}

for n in range(2, 50):
  knn = KNeighborsRegressor(n_neighbors=n)
  knn.fit(x_cluster10_train, y_cluster10_train)
  predict_knn10 = knn.predict(x_cluster10_test)
  r2_knn10 = r2_score(y_cluster10_test, predict_knn10)
  r2_scores[n] = r2_knn10

best_n_neighbors10 = max(r2_scores, key=r2_scores.get)
best_r2_score10 = r2_scores[best_n_neighbors10]

print(f"최적의 n_neighbors cluster 10: {best_n_neighbors10}")
print(f"최적의 R^2 cluster 10: {best_r2_score10}")
# Out:
# 최적의 n_neighbors cluster 5: 28
# 최적의 R^2 cluster 5: 0.9302955640919239
# 최적의 n_neighbors cluster 6: 19
# 최적의 R^2 cluster 6: 0.9171659088110227
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-c78346b69ba8> in <cell line: 36>()
#      37   knn = KNeighborsRegressor(n_neighbors=n)
#      38   knn.fit(x_cluster7_train, y_cluster7_train)
# ---> 39   predict_knn7 = knn.predict(x_cluster7_test)
#      40   r2_knn7 = r2_score(y_cluster7_test, predict_knn7)
#      41   r2_scores[n] = r2_knn7
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_regression.py in predict(self, X)
#     234             # In that case, we do not need the distances to perform
#     235             # the weighting so we do not compute them.
# --> 236             neigh_ind = self.kneighbors(X, return_distance=False)
#     237             neigh_dist = None
#     238         else:
#
# ...

# %%
knn1 = KNeighborsRegressor(n_neighbors=5)
knn1.fit(x_cluster1_train, y_cluster1_train)

knn2 = KNeighborsRegressor(n_neighbors=9)
knn2.fit(x_cluster2_train, y_cluster2_train)

knn3 = KNeighborsRegressor(n_neighbors=13)
knn3.fit(x_cluster3_train, y_cluster3_train)

knn4 = KNeighborsRegressor(n_neighbors=10)
knn4.fit(x_cluster4_train, y_cluster4_train)

knn5 = KNeighborsRegressor(n_neighbors=5)
knn5.fit(x_cluster5_train, y_cluster5_train)

knn6 = KNeighborsRegressor(n_neighbors=9)
knn6.fit(x_cluster6_train, y_cluster6_train)

knn7 = KNeighborsRegressor(n_neighbors=13)
knn7.fit(x_cluster7_train, y_cluster7_train)

knn8 = KNeighborsRegressor(n_neighbors=10)
knn8.fit(x_cluster8_train, y_cluster8_train)

knn9 = KNeighborsRegressor(n_neighbors=5)
knn9.fit(x_cluster9_train, y_cluster9_train)

knn10 = KNeighborsRegressor(n_neighbors=9)
knn10.fit(x_cluster10_train, y_cluster10_train)

# %%
knn1 = KNeighborsRegressor(n_neighbors=17)
knn1.fit(x_cluster1_train, y_cluster1_train)

knn2 = KNeighborsRegressor(n_neighbors=29)
knn2.fit(x_cluster2_train, y_cluster2_train)

knn3 = KNeighborsRegressor(n_neighbors=18)
knn3.fit(x_cluster3_train, y_cluster3_train)

knn4 = KNeighborsRegressor(n_neighbors=12)
knn4.fit(x_cluster4_train, y_cluster4_train)
# Out:
# KNeighborsRegressor(n_neighbors=12)

# %%
# MAE & R^2
r2 = r2_score(y_cluster1_test, knn1.predict(x_cluster1_test))
mae = mean_absolute_error(y_cluster1_test, knn1.predict(x_cluster1_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn1.predict(x_cluster1_test), columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 67.89
# R-squared (R^2): 0.93
#            Pred      Test
# 0    870.427059  1038.840
# 1    851.512941   949.680
# 2    892.147059   795.060
# 3    975.696471   957.150
# 4    779.254235   816.000
# 5    493.060588   501.000
# 6   1201.717059  1302.120
# 7    974.468588   979.620
# 8   1932.395294  1911.840
# 9    912.328235   987.000
# 10    42.307647    41.220
# 11   830.520000  1134.240
# 12     8.254118     7.980
# 13   292.510588   284.880
# 14   606.760588   594.900
# 15    95.464235    96.960
# 16   810.451765   789.120
# 17   761.209412   771.840
# 18   247.209059   250.800
# 19  1037.791412   876.960
# 20   736.442941   675.900
# 21  1680.840000  1682.640
# 22   398.456471   200.970
# 23  1032.417882  1113.480
# 24   942.284118   936.600
# 25   236.705294   241.920
# 26   178.228235   173.970
# 27   580.484706   569.620
# 28  1012.795529   982.020
# 29  1183.505294  1186.632
# 30   879.044118   867.840
# 31   930.670000   952.380
# ...

# %%
# MAE & R^2
r2 = r2_score(y_cluster2_test, knn2.predict(x_cluster2_test))
mae = mean_absolute_error(y_cluster2_test, knn2.predict(x_cluster2_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn2.predict(x_cluster2_test), columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 32.93
# R-squared (R^2): 0.93
#           Pred     Test
# 0   392.628966  397.840
# 1   598.686069  627.480
# 2    72.884724   56.520
# 3    15.421793   16.200
# 4   364.580241  383.980
# 5    47.324069   47.010
# 6   505.300138  571.880
# 7   115.351793   54.180
# 8   497.643103  548.880
# 9   909.533793  926.010
# 10   68.938759   71.050
# 11  374.337931  391.860
# 12   94.827897   51.590
# 13  433.977103  448.440
# 14  583.476621  597.680
# 15  199.349598  172.730
# 16  552.617379  560.880
# 17  335.847448  360.850
# 18  630.469345  648.180
# 19  438.280345  344.340
# 20   41.533103   27.120
# 21  158.408414  160.880
# 22  459.123448  462.740
# 23  235.266207  245.400
# 24  243.701828  277.490
# 25  236.559172  254.700
# 26  573.224069  577.120
# 27  445.088966  464.590
# 28  355.267931  453.990
# 29  422.471586  410.220
# 30  398.965862  367.490
# 31   99.174828   88.884
# 32  783.580345  833.400
# 33   28.804483   29.300
# 34  574.490759  566.240
# ...

# %%
# MAE & R^2
r2 = r2_score(y_cluster3_test, knn3.predict(x_cluster3_test))
mae = mean_absolute_error(y_cluster3_test, knn3.predict(x_cluster3_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn3.predict(x_cluster3_test), columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 112.79
# R-squared (R^2): 0.92
#            Pred     Test
# 0   2255.890000  2244.96
# 1   1346.070000  1606.68
# 2   1428.690000  1394.64
# 3   1575.776667  1568.34
# 4   2024.070000  1543.50
# 5   1194.691667   709.74
# 6    681.556667   701.82
# 7   1629.340000  1781.46
# 8   2635.220000  2623.50
# 9   1905.163333  1872.36
# 10  1800.953333  1789.92
# 11  1797.443333  1808.28
# 12  1933.443333  1902.60
# 13   499.662778   513.60
# 14  2669.211333  2640.60
# 15  2232.680000  2081.52
# 16  1087.380000   389.88
# 17  2170.900000  1983.60
# 18   951.425000   654.48
# 19  1127.676667  1226.88
# 20   160.002667   164.52
# 21   200.391778   203.04
# 22  1269.290000  1324.08
# 23  2243.213333  1846.80
# 24  2593.350000  1926.72
# 25  2093.950000  2093.76
# 26  1323.426667  1273.14
# 27  1951.816667  1932.30
# 28   852.561667  1610.28
# 29    40.131000    48.24
# 30   655.346667   711.18
# 31  1275.720000  1286.46
# 32   285.327889   250.92
# ...

# %%
# MAE & R^2
r2 = r2_score(y_cluster4_test, knn4.predict(x_cluster4_test))
mae = mean_absolute_error(y_cluster4_test, knn4.predict(x_cluster4_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn4.predict(x_cluster4_test), columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 2.67
# R-squared (R^2): 0.87
#          Pred     Test
# 0    3.652833    1.044
# 1   18.538167   18.770
# 2    2.849167    4.360
# 3   13.486667   13.000
# 4   99.801667  111.940
# 5    3.295625    3.705
# 6    2.534167    1.960
# 7    2.398000    2.508
# 8   24.890000   24.570
# 9    3.483333    3.380
# 10  24.814167   21.560
# 11  23.157500   36.970
# 12   5.877500    5.620
# 13   3.505500    3.110
# 14  50.392667   50.196
# 15   3.592500    4.640
# 16   2.087500    2.040
# 17   4.549167    4.060
# 18  40.726000   55.110
# 19   4.944167    3.150
# 20   1.698333    1.790
# 21   2.164667    2.030
# 22   3.744333    3.804
# 23  55.375000   65.310
# 24   8.201667    6.970
# 25   1.553333    1.660
# 26   7.595000    2.850
# 27  51.801667   54.770
# 28   3.436667    1.990
# 29  15.139417   17.720
# 30   4.768500    3.790
# 31   2.015417    1.900
# 32  11.785333   12.906
# 33  11.185833    6.530
# 34   9.130833    9.960
# 35   6.598333    6.800
# ...

# %%
# MAE & R^2
r2 = r2_score(y_cluster5_test, knn5.predict(x_cluster5_test))
mae = mean_absolute_error(y_cluster5_test, knn5.predict(x_cluster5_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn5.predict(x_cluster5_test), columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# MAE & R^2
r2 = r2_score(y_cluster6_test, knn6.predict(x_cluster6_test))
mae = mean_absolute_error(y_cluster6_test, knn6.predict(x_cluster6_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn6.predict(x_cluster6_test), columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# MAE & R^2
r2 = r2_score(y_cluster7_test, knn7.predict(x_cluster7_test))
mae = mean_absolute_error(y_cluster7_test, knn7.predict(x_cluster7_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn7.predict(x_cluster7_test), columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# MAE & R^2
r2 = r2_score(y_cluster8_test, knn8.predict(x_cluster8_test))
mae = mean_absolute_error(y_cluster8_test, knn8.predict(x_cluster8_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn8.predict(x_cluster8_test), columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# MAE & R^2
r2 = r2_score(y_cluster9_test, knn9.predict(x_cluster9_test))
mae = mean_absolute_error(y_cluster9_test, knn9.predict(x_cluster9_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn9.predict(x_cluster9_test), columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# MAE & R^2
r2 = r2_score(y_cluster10_test, knn10.predict(x_cluster10_test))
mae = mean_absolute_error(y_cluster10_test, knn10.predict(x_cluster10_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(knn10.predict(x_cluster10_test), columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Linear Regression

# %%
lr1 = LinearRegression()
lr1.fit(x_ff1_train, y_ff1_train)
predict_lr1 = lr1.predict(x_cluster1_test)

# MAE & R^2
r2 = r2_score(y_cluster1_test, predict_lr1)
mae = mean_absolute_error(y_cluster1_test, predict_lr1)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 79.39
# R-squared (R^2): 0.91
#            Pred      Test
# 0    921.184052  1038.840
# 1    844.089199   949.680
# 2    950.415459   795.060
# 3    970.671051   957.150
# 4    755.586030   816.000
# 5    505.115444   501.000
# 6   1139.088384  1302.120
# 7   1000.629255   979.620
# 8   1773.672526  1911.840
# 9    914.302595   987.000
# 10    83.438476    41.220
# 11   326.068002  1134.240
# 12    50.186579     7.980
# 13   319.994007   284.880
# 14   589.702605   594.900
# 15   145.918508    96.960
# 16   855.554769   789.120
# 17   750.579586   771.840
# 18   279.250974   250.800
# 19  1017.944113   876.960
# 20   757.484041   675.900
# 21  1655.056916  1682.640
# 22    65.382926   200.970
# 23  1017.936239  1113.480
# 24   927.131617   936.600
# 25   263.507797   241.920
# 26   204.694811   173.970
# 27   590.474789   569.620
# 28  1033.862420   982.020
# 29  1201.155213  1186.632
# 30   878.681685   867.840
# 31   964.918624   952.380
# ...

# %%
lr2 = LinearRegression()
lr2.fit(x_ff2_train, y_ff2_train)
predict_lr2 = lr2.predict(x_cluster2_test)

# MAE & R^2
r2 = r2_score(y_cluster2_test, predict_lr2)
mae = mean_absolute_error(y_cluster2_test, predict_lr2)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 39.50
# R-squared (R^2): 0.90
#            Pred     Test
# 0    389.239211  397.840
# 1    611.346670  627.480
# 2     81.113726   56.520
# 3     38.659791   16.200
# 4    382.860109  383.980
# 5     67.333190   47.010
# 6    414.888147  571.880
# 7     85.886828   54.180
# 8    565.893695  548.880
# 9   1023.526716  926.010
# 10    92.350421   71.050
# 11   377.814461  391.860
# 12    94.968888   51.590
# 13   444.114501  448.440
# 14   578.110396  597.680
# 15   197.665266  172.730
# 16   563.745416  560.880
# 17   329.241247  360.850
# 18   627.500607  648.180
# 19   402.777720  344.340
# 20    38.199477   27.120
# 21   178.656724  160.880
# 22   462.787237  462.740
# 23   244.894528  245.400
# 24   216.449176  277.490
# 25   273.522671  254.700
# 26   560.026094  577.120
# 27   456.665748  464.590
# 28   267.346880  453.990
# 29   436.432526  410.220
# 30   385.538522  367.490
# 31   116.687020   88.884
# 32   815.788569  833.400
# ...

# %%
lr3 = LinearRegression()
lr3.fit(x_ff3_train, y_ff3_train)
predict_lr3 = lr3.predict(x_cluster3_test)

# MAE & R^2
r2 = r2_score(y_cluster3_test, predict_lr3)
mae = mean_absolute_error(y_cluster3_test, predict_lr3)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 134.32
# R-squared (R^2): 0.89
#            Pred     Test
# 0   2209.897016  2244.96
# 1   1484.686968  1606.68
# 2   1450.438728  1394.64
# 3   1578.965032  1568.34
# 4   2001.846576  1543.50
# 5   1347.209123   709.74
# 6    714.399999   701.82
# 7   1431.760061  1781.46
# 8   2563.198318  2623.50
# 9   1899.934209  1872.36
# 10  1778.277522  1789.92
# 11  1554.875097  1808.28
# 12  1907.809684  1902.60
# 13   578.543377   513.60
# 14  2694.617147  2640.60
# 15  2243.719793  2081.52
# 16   801.905046   389.88
# 17  2344.214160  1983.60
# 18  1045.943033   654.48
# 19  1267.678407  1226.88
# 20   209.140765   164.52
# 21   274.351296   203.04
# 22  1324.106648  1324.08
# 23  1817.716736  1846.80
# 24  2624.628323  1926.72
# 25  2071.017765  2093.76
# 26  1349.408340  1273.14
# 27  1968.178951  1932.30
# 28   639.916173  1610.28
# 29   130.034155    48.24
# 30   698.851235   711.18
# 31  1274.182700  1286.46
# 32   322.091723   250.92
# ...

# %%
lr4 = LinearRegression()
lr4.fit(x_ff4_train, y_ff4_train)
predict_lr4 = lr4.predict(x_cluster4_test)

# MAE & R^2
r2 = r2_score(y_cluster4_test, predict_lr4)
mae = mean_absolute_error(y_cluster4_test, predict_lr4)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Mean Absolute Error (MAE): 3.23
# R-squared (R^2): 0.84
#           Pred     Test
# 0     5.831594    1.044
# 1    19.308874   18.770
# 2     4.266871    4.360
# 3    14.663229   13.000
# 4   103.165649  111.940
# 5     4.399780    3.705
# 6     3.390039    1.960
# 7     4.307422    2.508
# 8    26.787178   24.570
# 9     2.746729    3.380
# 10   16.309718   21.560
# 11   14.724381   36.970
# 12    5.896814    5.620
# 13    4.425585    3.110
# 14   44.659102   50.196
# 15    4.175965    4.640
# 16    2.945137    2.040
# 17    4.317208    4.060
# 18   48.633950   55.110
# 19    5.262733    3.150
# 20    3.625446    1.790
# 21    3.902689    2.030
# 22    4.367737    3.804
# 23   61.896629   65.310
# 24    6.810736    6.970
# 25    1.974840    1.660
# 26    3.884531    2.850
# 27   54.026023   54.770
# 28    3.244431    1.990
# 29   16.626351   17.720
# 30    2.845706    3.790
# 31    4.086073    1.900
# 32    7.551420   12.906
# 33    7.462053    6.530
# 34    9.900837    9.960
# ...

# %%
lr5 = LinearRegression()
lr5.fit(x_ff5_train, y_ff5_train)
predict_lr5 = lr5.predict(x_cluster5_test)

# MAE & R^2
r2 = r2_score(y_cluster5_test, predict_lr5)
mae = mean_absolute_error(y_cluster5_test, predict_lr5)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr5, columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
lr6 = LinearRegression()
lr6.fit(x_ff6_train, y_ff6_train)
predict_lr6 = lr6.predict(x_cluster6_test)

# MAE & R^2
r2 = r2_score(y_cluster6_test, predict_lr6)
mae = mean_absolute_error(y_cluster6_test, predict_lr6)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr6, columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
lr7 = LinearRegression()
lr7.fit(x_ff7_train, y_ff7_train)
predict_lr7 = lr7.predict(x_cluster7_test)

# MAE & R^2
r2 = r2_score(y_cluster7_test, predict_lr7)
mae = mean_absolute_error(y_cluster7_test, predict_lr7)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr7, columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
lr8 = LinearRegression()
lr8.fit(x_ff8_train, y_ff8_train)
predict_lr8 = lr8.predict(x_cluster8_test)

# MAE & R^2
r2 = r2_score(y_cluster8_test, predict_lr8)
mae = mean_absolute_error(y_cluster8_test, predict_lr8)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr8, columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
lr9 = LinearRegression()
lr9.fit(x_ff9_train, y_ff9_train)
predict_lr9 = lr9.predict(x_cluster9_test)

# MAE & R^2
r2 = r2_score(y_cluster9_test, predict_lr9)
mae = mean_absolute_error(y_cluster9_test, predict_lr9)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr9, columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
lr10 = LinearRegression()
lr10.fit(x_ff10_train, y_ff10_train)
predict_lr10 = lr10.predict(x_cluster10_test)

# MAE & R^2
r2 = r2_score(y_cluster10_test, predict_lr10)
mae = mean_absolute_error(y_cluster10_test, predict_lr10)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측값과 실제값 차이
results = pd.DataFrame(predict_lr10, columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # SVR

# %% [markdown]
# # LSTM

# %%
model_lstm1 = Sequential()
model_lstm1.add(LSTM(units=50, activation='relu', input_shape=(x_ff1_train.shape[1], 1)))
model_lstm1.add(Dense(units=1))

model_lstm1.compile(optimizer='adam', loss='mean_squared_error')

model_lstm1.fit(x_ff1_train, y_ff1_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster1_test, model_lstm1.predict(x_cluster1_test))
mae = mean_absolute_error(y_cluster1_test, model_lstm1.predict(x_cluster1_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm1.predict(x_cluster1_test), columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# 9605/9605 [==============================] - 40s 4ms/step - loss: 34492.8203
# Epoch 2/50
# 9605/9605 [==============================] - 39s 4ms/step - loss: 21468.4102
# Epoch 3/50
# 9605/9605 [==============================] - 38s 4ms/step - loss: 21234.4492
# Epoch 4/50
# 9605/9605 [==============================] - 38s 4ms/step - loss: 21054.8184
# Epoch 5/50
# 9605/9605 [==============================] - 37s 4ms/step - loss: 20929.4297
# Epoch 6/50
# 9605/9605 [==============================] - 37s 4ms/step - loss: 20747.8555
# Epoch 7/50
# 9605/9605 [==============================] - 37s 4ms/step - loss: 20496.1270
# Epoch 8/50
# 9605/9605 [==============================] - 37s 4ms/step - loss: 20035.9023
# Epoch 9/50
# 9605/9605 [==============================] - 37s 4ms/step - loss: 19666.0410
# Epoch 10/50
# 9605/9605 [==============================] - 37s 4ms/step - loss: 19437.5098
# Epoch 11/50
# ...

# %%
model_lstm2 = Sequential()
model_lstm2.add(LSTM(units=50, activation='relu', input_shape=(x_ff2_train.shape[1], 1)))
model_lstm2.add(Dense(units=1))

model_lstm2.compile(optimizer='adam', loss='mean_squared_error')

model_lstm2.fit(x_ff2_train, y_ff2_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster2_test, model_lstm2.predict(x_cluster2_test))
mae = mean_absolute_error(y_cluster2_test, model_lstm2.predict(x_cluster2_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm2.predict(x_cluster2_test), columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# 49058/49058 [==============================] - 189s 4ms/step - loss: 6221.7471
# Epoch 2/50
# 49058/49058 [==============================] - 188s 4ms/step - loss: 5318.0093
# Epoch 3/50
# 49058/49058 [==============================] - 187s 4ms/step - loss: 5149.5249
# Epoch 4/50
# 49058/49058 [==============================] - 187s 4ms/step - loss: 5061.4434
# Epoch 5/50
# 49058/49058 [==============================] - 187s 4ms/step - loss: 4991.5288
# Epoch 6/50
# 49058/49058 [==============================] - 194s 4ms/step - loss: 4946.2241
# Epoch 7/50
# 49058/49058 [==============================] - 185s 4ms/step - loss: 4916.5049
# Epoch 8/50
# 49058/49058 [==============================] - 189s 4ms/step - loss: 4896.7227
# Epoch 9/50
# 49058/49058 [==============================] - 188s 4ms/step - loss: 4867.9468
# Epoch 10/50
# 49058/49058 [==============================] - 187s 4ms/step - loss: 4836.0811
# Epoch 11/50
# ...

# %%
model_lstm3 = Sequential()
model_lstm3.add(LSTM(units=50, activation='relu', input_shape=(x_ff3_train.shape[1], 1)))
model_lstm3.add(Dense(units=1))

model_lstm3.compile(optimizer='adam', loss='mean_squared_error')

model_lstm3.fit(x_ff3_train, y_ff3_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster3_test, model_lstm3.predict(x_cluster3_test))
mae = mean_absolute_error(y_cluster3_test, model_lstm3.predict(x_cluster3_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm3.predict(x_cluster3_test), columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# 7095/7095 [==============================] - 30s 4ms/step - loss: 151415.7031
# Epoch 2/50
# 7095/7095 [==============================] - 27s 4ms/step - loss: 89975.8281
# Epoch 3/50
# 7095/7095 [==============================] - 27s 4ms/step - loss: 88545.2266
# Epoch 4/50
# 7095/7095 [==============================] - 28s 4ms/step - loss: 87734.9766
# Epoch 5/50
# 7095/7095 [==============================] - 27s 4ms/step - loss: 86712.2422
# Epoch 6/50
# 7095/7095 [==============================] - 27s 4ms/step - loss: 85842.9375
# Epoch 7/50
# 7095/7095 [==============================] - 28s 4ms/step - loss: 85003.1406
# Epoch 8/50
# 7095/7095 [==============================] - 27s 4ms/step - loss: 83960.5312
# Epoch 9/50
# 7095/7095 [==============================] - 27s 4ms/step - loss: 82704.8125
# Epoch 10/50
# 7095/7095 [==============================] - 28s 4ms/step - loss: 80927.5156
# Epoch 11/50
# ...

# %%
model_lstm4 = Sequential()
model_lstm4.add(LSTM(units=50, activation='relu', input_shape=(x_ff4_train.shape[1], 1)))
model_lstm4.add(Dense(units=1))

model_lstm4.compile(optimizer='adam', loss='mean_squared_error')

model_lstm4.fit(x_ff4_train, y_ff4_train, epochs=15, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster4_test, model_lstm4.predict(x_cluster4_test))
mae = mean_absolute_error(y_cluster4_test, model_lstm4.predict(x_cluster4_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm4.predict(x_cluster4_test), columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/15
# 113079/113079 [==============================] - 499s 4ms/step - loss: 47.3242
# Epoch 2/15
# 113079/113079 [==============================] - 476s 4ms/step - loss: 46.0183
# Epoch 3/15
# 113079/113079 [==============================] - 487s 4ms/step - loss: 47.8446
# Epoch 4/15
# 113079/113079 [==============================] - 479s 4ms/step - loss: 45.8703
# Epoch 5/15
#  50497/113079 [============>.................] - ETA: 4:23 - loss: 44.0087

# %%
model_lstm5 = Sequential()
model_lstm5.add(LSTM(units=50, activation='relu', input_shape=(x_ff5_train.shape[1], 1)))
model_lstm5.add(Dense(units=1))

model_lstm5.compile(optimizer='adam', loss='mean_squared_error')

model_lstm5.fit(x_ff5_train, y_ff5_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster5_test, model_lstm5.predict(x_cluster5_test))
mae = mean_absolute_error(y_cluster5_test, model_lstm5.predict(x_cluster5_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm5.predict(x_cluster5_test), columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_lstm6 = Sequential()
model_lstm6.add(LSTM(units=50, activation='relu', input_shape=(x_ff6_train.shape[1], 1)))
model_lstm6.add(Dense(units=1))

model_lstm6.compile(optimizer='adam', loss='mean_squared_error')

model_lstm6.fit(x_ff6_train, y_ff6_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster6_test, model_lstm6.predict(x_cluster6_test))
mae = mean_absolute_error(y_cluster6_test, model_lstm6.predict(x_cluster6_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm6.predict(x_cluster6_test), columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_lstm7 = Sequential()
model_lstm7.add(LSTM(units=50, activation='relu', input_shape=(x_ff7_train.shape[1], 1)))
model_lstm7.add(Dense(units=1))

model_lstm7.compile(optimizer='adam', loss='mean_squared_error')

model_lstm7.fit(x_ff7_train, y_ff7_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster7_test, model_lstm7.predict(x_cluster7_test))
mae = mean_absolute_error(y_cluster7_test, model_lstm7.predict(x_cluster7_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm7.predict(x_cluster7_test), columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_lstm8 = Sequential()
model_lstm8.add(LSTM(units=50, activation='relu', input_shape=(x_ff8_train.shape[1], 1)))
model_lstm8.add(Dense(units=1))

model_lstm8.compile(optimizer='adam', loss='mean_squared_error')

model_lstm8.fit(x_ff8_train, y_ff8_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster8_test, model_lstm8.predict(x_cluster8_test))
mae = mean_absolute_error(y_cluster8_test, model_lstm8.predict(x_cluster8_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm8.predict(x_cluster8_test), columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_lstm9 = Sequential()
model_lstm9.add(LSTM(units=50, activation='relu', input_shape=(x_ff9_train.shape[1], 1)))
model_lstm9.add(Dense(units=1))

model_lstm9.compile(optimizer='adam', loss='mean_squared_error')

model_lstm9.fit(x_ff9_train, y_ff9_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster9_test, model_lstm9.predict(x_cluster9_test))
mae = mean_absolute_error(y_cluster9_test, model_lstm9.predict(x_cluster9_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm9.predict(x_cluster9_test), columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_lstm10 = Sequential()
model_lstm10.add(LSTM(units=50, activation='relu', input_shape=(x_ff10_train.shape[1], 1)))
model_lstm10.add(Dense(units=1))

model_lstm10.compile(optimizer='adam', loss='mean_squared_error')

model_lstm10.fit(x_ff10_train, y_ff10_train, epochs=50, batch_size=32)

# MAE, R2 Score
r2 = r2_score(y_cluster10_test, model_lstm10.predict(x_cluster10_test))
mae = mean_absolute_error(y_cluster10_test, model_lstm10.predict(x_cluster10_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_lstm10.predict(x_cluster10_test), columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Random Forest

# %%
rf1 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search1 = GridSearchCV(estimator=rf1,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search1.fit(x_ff1_train, y_ff1_train)


best_params_rf1 = grid_search1.best_params_
best_score_rf1 = np.sqrt(-grid_search1.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf1 = grid_search1.best_estimator_

predict_rf1 = best_rf1.predict(x_cluster1_test)

# MAE, R2 Score
r2 = r2_score(y_cluster1_test, predict_rf1)
mae = mean_absolute_error(y_cluster1_test, predict_rf1)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf2 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search2 = GridSearchCV(estimator=rf2,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search2.fit(x_ff2_train, y_ff2_train)


best_params_rf2 = grid_search2.best_params_
best_score_rf2 = np.sqrt(-grid_search2.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf2 = grid_search2.best_estimator_

predict_rf2 = best_rf2.predict(x_cluster2_test)

# MAE, R2 Score
r2 = r2_score(y_cluster2_test, predict_rf2)
mae = mean_absolute_error(y_cluster2_test, predict_rf2)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf3 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search3 = GridSearchCV(estimator=rf3,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search3.fit(x_ff3_train, y_ff3_train)


best_params_rf3 = grid_search3.best_params_
best_score_rf3 = np.sqrt(-grid_search3.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf3 = grid_search3.best_estimator_

predict_rf3 = best_rf3.predict(x_cluster3_test)

# MAE, R2 Score
r2 = r2_score(y_cluster3_test, predict_rf3)
mae = mean_absolute_error(y_cluster3_test, predict_rf3)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf4 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search4 = GridSearchCV(estimator=rf4,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search4.fit(x_ff4_train, y_ff4_train)


best_params_rf4 = grid_search4.best_params_
best_score_rf4 = np.sqrt(-grid_search4.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf4 = grid_search4.best_estimator_

predict_rf4 = best_rf4.predict(x_cluster4_test)

# MAE, R2 Score
r2 = r2_score(y_cluster4_test, predict_rf4)
mae = mean_absolute_error(y_cluster4_test, predict_rf4)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf5 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search5 = GridSearchCV(estimator=rf5,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search5.fit(x_ff5_train, y_ff5_train)


best_params_rf5 = grid_search5.best_params_
best_score_rf5 = np.sqrt(-grid_search5.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf5 = grid_search5.best_estimator_

predict_rf5 = best_rf5.predict(x_cluster5_test)

# MAE, R2 Score
r2 = r2_score(y_cluster5_test, predict_rf5)
mae = mean_absolute_error(y_cluster5_test, predict_rf5)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf5, columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf6 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search6 = GridSearchCV(estimator=rf6,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search6.fit(x_ff6_train, y_ff6_train)


best_params_rf6 = grid_search6.best_params_
best_score_rf6 = np.sqrt(-grid_search6.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf6 = grid_search6.best_estimator_

predict_rf6 = best_rf6.predict(x_cluster6_test)

# MAE, R2 Score
r2 = r2_score(y_cluster6_test, predict_rf6)
mae = mean_absolute_error(y_cluster6_test, predict_rf6)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf6, columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf7 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search7 = GridSearchCV(estimator=rf7,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search7.fit(x_ff7_train, y_ff7_train)


best_params_rf7 = grid_search7.best_params_
best_score_rf7 = np.sqrt(-grid_search7.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf7 = grid_search7.best_estimator_

predict_rf7 = best_rf7.predict(x_cluster7_test)

# MAE, R2 Score
r2 = r2_score(y_cluster7_test, predict_rf7)
mae = mean_absolute_error(y_cluster7_test, predict_rf7)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf7, columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf8 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}


grid_search8 = GridSearchCV(estimator=rf8,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search8.fit(x_ff8_train, y_ff8_train)


best_params_rf8 = grid_search8.best_params_
best_score_rf8 = np.sqrt(-grid_search8.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf8 = grid_search8.best_estimator_

predict_rf8 = best_rf8.predict(x_cluster8_test)

# MAE, R2 Score
r2 = r2_score(y_cluster8_test, predict_rf8)
mae = mean_absolute_error(y_cluster8_test, predict_rf8)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf8, columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf9 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search9 = GridSearchCV(estimator=rf9,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search9.fit(x_ff9_train, y_ff9_train)


best_params_rf9 = grid_search9.best_params_
best_score_rf9 = np.sqrt(-grid_search9.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf9 = grid_search9.best_estimator_

predict_rf9 = best_rf9.predict(x_cluster9_test)

# MAE, R2 Score
r2 = r2_score(y_cluster9_test, predict_rf9)
mae = mean_absolute_error(y_cluster9_test, predict_rf9)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf9, columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
rf10 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search10 = GridSearchCV(estimator=rf10,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search10.fit(x_ff10_train, y_ff10_train)


best_params_rf10 = grid_search10.best_params_
best_score_rf10 = np.sqrt(-grid_search10.best_score_)  # 음수 MSE를 양수 변환 후 RMSE


# 최적 하이퍼파라미터 사용하여 예측
best_rf10 = grid_search10.best_estimator_

predict_rf10 = best_rf10.predict(x_cluster10_test)

# MAE, R2 Score
r2 = r2_score(y_cluster10_test, predict_rf10)
mae = mean_absolute_error(y_cluster10_test, predict_rf10)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_rf10, columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # LGBMRegressor

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm1 = lgb.LGBMRegressor(random_state=42)

grid_search1 = GridSearchCV(
    lgbm1, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search1.fit(x_ff1_train, y_ff1_train)

best_params1 = grid_search1.best_params_

best_lgbm1 = lgb.LGBMRegressor(**best_params1, random_state=42)
best_lgbm1.fit(x_ff1_train, y_ff1_train)

predict_lgbm1 = best_lgbm1.predict(x_cluster1_test)

# MAE, R2 Score
r2 = r2_score(y_cluster1_test, predict_lgbm1)
mae = mean_absolute_error(y_cluster1_test, predict_lgbm1)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm2 = lgb.LGBMRegressor(random_state=42)

grid_search2 = GridSearchCV(
    lgbm2, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search2.fit(x_ff2_train, y_ff2_train)

best_params2 = grid_search2.best_params_

best_lgbm2 = lgb.LGBMRegressor(**best_params2, random_state=42)
best_lgbm2.fit(x_ff2_train, y_ff2_train)

predict_lgbm2 = best_lgbm2.predict(x_cluster2_test)

# MAE, R2 Score
r2 = r2_score(y_cluster2_test, predict_lgbm2)
mae = mean_absolute_error(y_cluster2_test, predict_lgbm2)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm3 = lgb.LGBMRegressor(random_state=42)

grid_search3 = GridSearchCV(
    lgbm3, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search3.fit(x_ff3_train, y_ff3_train)

best_params3 = grid_search3.best_params_

best_lgbm3 = lgb.LGBMRegressor(**best_params3, random_state=42)
best_lgbm3.fit(x_ff3_train, y_ff3_train)

predict_lgbm3 = best_lgbm3.predict(x_cluster3_test)

# MAE, R2 Score
r2 = r2_score(y_cluster3_test, predict_lgbm3)
mae = mean_absolute_error(y_cluster3_test, predict_lgbm3)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm4 = lgb.LGBMRegressor(random_state=42)

grid_search4 = GridSearchCV(
    lgbm4, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search4.fit(x_ff1_train, y_ff1_train)

best_params4 = grid_search4.best_params_

best_lgbm4 = lgb.LGBMRegressor(**best_params4, random_state=42)
best_lgbm4.fit(x_ff4_train, y_ff4_train)

predict_lgbm4 = best_lgbm4.predict(x_cluster4_test)

# MAE, R2 Score
r2 = r2_score(y_cluster4_test, predict_lgbm4)
mae = mean_absolute_error(y_cluster4_test, predict_lgbm4)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm5 = lgb.LGBMRegressor(random_state=42)

grid_search5 = GridSearchCV(
    lgbm5, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search5.fit(x_ff5_train, y_ff5_train)

best_params5 = grid_search5.best_params_

best_lgbm5 = lgb.LGBMRegressor(**best_params5, random_state=42)
best_lgbm5.fit(x_ff5_train, y_ff5_train)

predict_lgbm5 = best_lgbm5.predict(x_cluster5_test)

# MAE, R2 Score
r2 = r2_score(y_cluster5_test, predict_lgbm5)
mae = mean_absolute_error(y_cluster5_test, predict_lgbm5)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm5, columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm6 = lgb.LGBMRegressor(random_state=42)

grid_search6 = GridSearchCV(
    lgbm6, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search6.fit(x_ff6_train, y_ff6_train)

best_params6 = grid_search6.best_params_

best_lgbm6 = lgb.LGBMRegressor(**best_params6, random_state=42)
best_lgbm6.fit(x_ff6_train, y_ff6_train)

predict_lgbm6 = best_lgbm6.predict(x_cluster6_test)

# MAE, R2 Score
r2 = r2_score(y_cluster6_test, predict_lgbm6)
mae = mean_absolute_error(y_cluster6_test, predict_lgbm6)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm6, columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm7 = lgb.LGBMRegressor(random_state=42)

grid_search7 = GridSearchCV(
    lgbm7, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search7.fit(x_ff7_train, y_ff7_train)

best_params7 = grid_search4.best_params_

best_lgbm7 = lgb.LGBMRegressor(**best_params7, random_state=42)
best_lgbm7.fit(x_ff7_train, y_ff7_train)

predict_lgbm7 = best_lgbm7.predict(x_cluster7_test)

# MAE, R2 Score
r2 = r2_score(y_cluster7_test, predict_lgbm7)
mae = mean_absolute_error(y_cluster7_test, predict_lgbm7)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm7, columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm8 = lgb.LGBMRegressor(random_state=42)

grid_search8 = GridSearchCV(
    lgbm8, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search8.fit(x_ff8_train, y_ff8_train)

best_params8 = grid_search8.best_params_

best_lgbm8 = lgb.LGBMRegressor(**best_params8, random_state=42)
best_lgbm8.fit(x_ff8_train, y_ff8_train)

predict_lgbm8 = best_lgbm8.predict(x_cluster8_test)

# MAE, R2 Score
r2 = r2_score(y_cluster8_test, predict_lgbm8)
mae = mean_absolute_error(y_cluster8_test, predict_lgbm8)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm8, columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm9 = lgb.LGBMRegressor(random_state=42)

grid_search9 = GridSearchCV(
    lgbm9, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search9.fit(x_ff9_train, y_ff9_train)

best_params9 = grid_search9.best_params_

best_lgbm9 = lgb.LGBMRegressor(**best_params9, random_state=42)
best_lgbm9.fit(x_ff9_train, y_ff9_train)

predict_lgbm9 = best_lgbm9.predict(x_cluster9_test)

# MAE, R2 Score
r2 = r2_score(y_cluster9_test, predict_lgbm9)
mae = mean_absolute_error(y_cluster9_test, predict_lgbm9)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm9, columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid_lgbm = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

lgbm10 = lgb.LGBMRegressor(random_state=42)

grid_search10 = GridSearchCV(
    lgbm10, param_grid_lgbm, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search10.fit(x_ff10_train, y_ff10_train)

best_params10 = grid_search10.best_params_

best_lgbm10 = lgb.LGBMRegressor(**best_params10, random_state=42)
best_lgbm10.fit(x_ff10_train, y_ff10_train)

predict_lgbm10 = best_lgbm10.predict(x_cluster10_test)

# MAE, R2 Score
r2 = r2_score(y_cluster10_test, predict_lgbm10)
mae = mean_absolute_error(y_cluster10_test, predict_lgbm10)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_lgbm10, columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # MLPRegressor

# %%
model_mlp1 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

# MLPRegressor 모델을 훈련
model_mlp1.fit(x_ff1_train, y_ff1_train)

predict_mlp1 = model_mlp1.predict(x_cluster1_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster1_test, predict_mlp1)
mae = mean_absolute_error(y_cluster1_test, predict_mlp1)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp2 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp2.fit(x_ff2_train, y_ff2_train)

predict_mlp2 = model_mlp2.predict(x_cluster2_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster2_test, predict_mlp2)
mae = mean_absolute_error(y_cluster2_test, predict_mlp2)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp3 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp3.fit(x_ff3_train, y_ff3_train)

predict_mlp3 = model_mlp3.predict(x_cluster3_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster3_test, predict_mlp3)
mae = mean_absolute_error(y_cluster3_test, predict_mlp3)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp4 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp4.fit(x_ff4_train, y_ff4_train)

predict_mlp4 = model_mlp4.predict(x_cluster4_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster4_test, predict_mlp4)
mae = mean_absolute_error(y_cluster4_test, predict_mlp4)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp5 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp5.fit(x_ff5_train, y_ff5_train)

predict_mlp5 = model_mlp5.predict(x_cluster5_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster5_test, predict_mlp5)
mae = mean_absolute_error(y_cluster5_test, predict_mlp5)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp5, columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp6 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp6.fit(x_ff6_train, y_ff6_train)

predict_mlp6 = model_mlp6.predict(x_cluster6_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster6_test, predict_mlp6)
mae = mean_absolute_error(y_cluster6_test, predict_mlp6)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp6, columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp7 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp7.fit(x_ff7_train, y_ff7_train)

predict_mlp7 = model_mlp7.predict(x_cluster7_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster7_test, predict_mlp7)
mae = mean_absolute_error(y_cluster7_test, predict_mlp7)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp7, columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp8 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp8.fit(x_ff8_train, y_ff8_train)

predict_mlp8 = model_mlp8.predict(x_cluster8_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster8_test, predict_mlp8)
mae = mean_absolute_error(y_cluster8_test, predict_mlp8)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp8, columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp9 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp9.fit(x_ff9_train, y_ff9_train)

predict_mlp9 = model_mlp9.predict(x_cluster9_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster9_test, predict_mlp9)
mae = mean_absolute_error(y_cluster9_test, predict_mlp9)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp9, columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
model_mlp10 = MLPRegressor(
    hidden_layer_sizes=(64, 32),  # 'hidden_layer_sizes' 설정
    activation='relu',
    solver='adam',
    learning_rate='adaptive',
    max_iter=1000  # max_iter 파라미터가 모델이 수렴할 때까지의 최대 반복 횟수를 설정
)

model_mlp10.fit(x_ff10_train, y_ff10_train)

predict_mlp10 = model_mlp10.predict(x_cluster10_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster10_test, predict_mlp10)
mae = mean_absolute_error(y_cluster10_test, predict_mlp10)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_mlp10, columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Gradient Boosting

# %%
param_grid = {
    'n_estimators': [50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

gbr1 = GradientBoostingRegressor(random_state=42)

grid_search1 = GridSearchCV(
    gbr1, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search1.fit(x_ff1_train, y_ff1_train)

best_params1 = grid_search1.best_params_
print(f'Лучшие параметры: {best_params1}')

best_gbr1 = GradientBoostingRegressor(**best_params1, random_state=42)
best_gbr1.fit(x_ff1_train, y_ff1_train)

predict_gbr1 = best_gbr1.predict(x_cluster1_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster1_test, predict_gbr1)
mae = mean_absolute_error(y_cluster1_test, predict_gbr1)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
param_grid = {
    'n_estimators': [50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5]
}

gbr2 = GradientBoostingRegressor(random_state=42)

grid_search2 = GridSearchCV(
    gbr2, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search2.fit(x_ff2_train, y_ff2_train)

best_params2 = grid_search2.best_params_
print(f'Лучшие параметры: {best_params2}')

best_gbr2 = GradientBoostingRegressor(**best_params2, random_state=42)
best_gbr2.fit(x_ff2_train, y_ff2_train)

predict_gbr2 = best_gbr2.predict(x_cluster2_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster2_test, predict_gbr2)
mae = mean_absolute_error(y_cluster2_test, predict_gbr2)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr3 = GradientBoostingRegressor(random_state=42)

grid_search3 = GridSearchCV(
    gbr3, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search3.fit(x_ff3_train, y_ff3_train)

best_params3 = grid_search3.best_params_
print(f'Лучшие параметры: {best_params3}')

best_gbr3 = GradientBoostingRegressor(**best_params3, random_state=42)
best_gbr3.fit(x_ff3_train, y_ff3_train)

predict_gbr3 = best_gbr3.predict(x_cluster3_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster3_test, predict_gbr3)
mae = mean_absolute_error(y_cluster3_test, predict_gbr3)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr4 = GradientBoostingRegressor(random_state=42)

grid_search4 = GridSearchCV(
    gbr4, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search4.fit(x_ff4_train, y_ff4_train)

best_params4 = grid_search4.best_params_
print(f'Лучшие параметры: {best_params4}')

best_gbr4 = GradientBoostingRegressor(**best_params4, random_state=42)
best_gbr4.fit(x_ff4_train, y_ff4_train)

predict_gbr4 = best_gbr4.predict(x_cluster4_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster4_test, predict_gbr4)
mae = mean_absolute_error(y_cluster4_test, predict_gbr4)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr5 = GradientBoostingRegressor(random_state=42)

grid_search5 = GridSearchCV(
    gbr5, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search5.fit(x_ff5_train, y_ff5_train)

best_params5 = grid_search5.best_params_
print(f'Лучшие параметры: {best_params5}')

best_gbr5 = GradientBoostingRegressor(**best_params5, random_state=42)
best_gbr5.fit(x_ff5_train, y_ff5_train)

predict_gbr5 = best_gbr5.predict(x_cluster5_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster5_test, predict_gbr5)
mae = mean_absolute_error(y_cluster5_test, predict_gbr5)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr5, columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr6 = GradientBoostingRegressor(random_state=42)

grid_search6 = GridSearchCV(
    gbr6, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search6.fit(x_ff6_train, y_ff6_train)

best_params6 = grid_search6.best_params_
print(f'Лучшие параметры: {best_params6}')

best_gbr6 = GradientBoostingRegressor(**best_params6, random_state=42)
best_gbr6.fit(x_ff6_train, y_ff6_train)

predict_gbr6 = best_gbr6.predict(x_cluster6_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster6_test, predict_gbr6)
mae = mean_absolute_error(y_cluster6_test, predict_gbr6)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr6, columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr7 = GradientBoostingRegressor(random_state=42)

grid_search7 = GridSearchCV(
    gbr7, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search7.fit(x_ff7_train, y_ff7_train)

best_params7 = grid_search7.best_params_
print(f'Лучшие параметры: {best_params7}')

best_gbr7 = GradientBoostingRegressor(**best_params7, random_state=42)
best_gbr7.fit(x_ff7_train, y_ff7_train)

predict_gbr7 = best_gbr7.predict(x_cluster7_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster7_test, predict_gbr7)
mae = mean_absolute_error(y_cluster7_test, predict_gbr7)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr7, columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr8 = GradientBoostingRegressor(random_state=42)

grid_search8 = GridSearchCV(
    gbr8, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search8.fit(x_ff8_train, y_ff8_train)

best_params8 = grid_search8.best_params_
print(f'Лучшие параметры: {best_params8}')

best_gbr8 = GradientBoostingRegressor(**best_params8, random_state=42)
best_gbr8.fit(x_ff8_train, y_ff8_train)

predict_gbr8 = best_gbr8.predict(x_cluster8_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster8_test, predict_gbr8)
mae = mean_absolute_error(y_cluster8_test, predict_gbr8)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr8, columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr9 = GradientBoostingRegressor(random_state=42)

grid_search9 = GridSearchCV(
    gbr9, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search9.fit(x_ff9_train, y_ff9_train)

best_params9 = grid_search9.best_params_
print(f'Лучшие параметры: {best_params9}')

best_gbr9 = GradientBoostingRegressor(**best_params9, random_state=42)
best_gbr9.fit(x_ff9_train, y_ff9_train)

predict_gbr9 = best_gbr9.predict(x_cluster9_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster9_test, predict_gbr9)
mae = mean_absolute_error(y_cluster9_test, predict_gbr9)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr9, columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
gbr10 = GradientBoostingRegressor(random_state=42)

grid_search10 = GridSearchCV(
    gbr10, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

grid_search10.fit(x_ff10_train, y_ff10_train)

best_params10 = grid_search10.best_params_
print(f'Лучшие параметры: {best_params10}')

best_gbr10 = GradientBoostingRegressor(**best_params10, random_state=42)
best_gbr10.fit(x_ff10_train, y_ff10_train)

predict_gbr10 = best_gbr10.predict(x_cluster10_test)

# MAE, R^2 Score
r2 = r2_score(y_cluster10_test, predict_gbr10)
mae = mean_absolute_error(y_cluster10_test, predict_gbr10)

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_gbr10, columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Neural Network

# %%
x_train1, x_val1, y_train1, y_val1 = train_test_split(
    x_ff1_train, y_ff1_train, test_size=0.2, random_state=42)

model_nn1 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn1.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn1 = model_nn1.fit(x_train1, y_train1, epochs=150,
                            validation_data=(x_val1, y_val1))

# MAE, R^2 Score
r2 = r2_score(y_cluster1_test, model_nn1.predict(x_cluster1_test))
mae = mean_absolute_error(y_cluster1_test, model_nn1.predict(x_cluster1_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn1.predict(x_cluster1_test), columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train2, x_val2, y_train2, y_val2 = train_test_split(
    x_ff2_train, y_ff2_train, test_size=0.2, random_state=42)

model_nn2 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn2.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn2 = model_nn2.fit(x_train2, y_train2, epochs=150,
                            validation_data=(x_val2, y_val2))

# MAE, R^2 Score
r2 = r2_score(y_cluster2_test, model_nn2.predict(x_cluster2_test))
mae = mean_absolute_error(y_cluster2_test, model_nn2.predict(x_cluster2_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn2.predict(x_cluster2_test), columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train3, x_val3, y_train3, y_val3 = train_test_split(
    x_ff3_train, y_ff3_train, test_size=0.2, random_state=42)

model_nn3 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn3.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn3 = model_nn3.fit(x_train3, y_train3, epochs=150,
                            validation_data=(x_val3, y_val3))

# MAE, R^2 Score
r2 = r2_score(y_cluster3_test, model_nn3.predict(x_cluster3_test))
mae = mean_absolute_error(y_cluster3_test, model_nn3.predict(x_cluster3_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn3.predict(x_cluster3_test), columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train4, x_val4, y_train4, y_val4 = train_test_split(
    x_ff4_train, y_ff4_train, test_size=0.2, random_state=42)

model_nn4 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn4.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn4 = model_nn4.fit(x_train4, y_train4, epochs=150,
                            validation_data=(x_val4, y_val4))

# MAE, R^2 Score
r2 = r2_score(y_cluster4_test, model_nn4.predict(x_cluster4_test))
mae = mean_absolute_error(y_cluster4_test, model_nn4.predict(x_cluster4_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn4.predict(x_cluster4_test), columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train5, x_val5, y_train5, y_val5 = train_test_split(
    x_ff5_train, y_ff5_train, test_size=0.2, random_state=42)

model_nn5 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn5.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn5 = model_nn5.fit(x_train5, y_train5, epochs=150,
                            validation_data=(x_val5, y_val5))

# MAE, R^2 Score
r2 = r2_score(y_cluster5_test, model_nn5.predict(x_cluster5_test))
mae = mean_absolute_error(y_cluster5_test, model_nn5.predict(x_cluster5_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn5.predict(x_cluster5_test), columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train6, x_val6, y_train6, y_val6 = train_test_split(
    x_ff6_train, y_ff6_train, test_size=0.2, random_state=42)

model_nn6 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn6.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn6 = model_nn6.fit(x_train6, y_train6, epochs=150,
                            validation_data=(x_val6, y_val6))

# MAE, R^2 Score
r2 = r2_score(y_cluster6_test, model_nn6.predict(x_cluster6_test))
mae = mean_absolute_error(y_cluster6_test, model_nn6.predict(x_cluster6_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn6.predict(x_cluster6_test), columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train7, x_val7, y_train7, y_val7 = train_test_split(
    x_ff7_train, y_ff7_train, test_size=0.2, random_state=42)

model_nn7 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn7.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn7 = model_nn7.fit(x_train7, y_train7, epochs=150,
                            validation_data=(x_val7, y_val7))

# MAE, R^2 Score
r2 = r2_score(y_cluster7_test, model_nn7.predict(x_cluster7_test))
mae = mean_absolute_error(y_cluster7_test, model_nn7.predict(x_cluster7_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn7predict(x_cluster7_test), columns=['Pred'])
y_test_new = y_cluster7_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train8, x_val8, y_train8, y_val8 = train_test_split(
    x_ff8_train, y_ff8_train, test_size=0.2, random_state=42)

model_nn8 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn8.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn8 = model_nn8.fit(x_train8, y_train8, epochs=150,
                            validation_data=(x_val8, y_val8))

# MAE, R^2 Score
r2 = r2_score(y_cluster8_test, model_nn8.predict(x_cluster8_test))
mae = mean_absolute_error(y_cluster8_test, model_nn8.predict(x_cluster8_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn8.predict(x_cluster8_test), columns=['Pred'])
y_test_new = y_cluster8_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train9, x_val9, y_train9, y_val9 = train_test_split(
    x_ff9_train, y_ff9_train, test_size=0.2, random_state=42)

model_nn9 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)
])

model_nn9.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn9 = model_nn9.fit(x_train9, y_train9, epochs=150,
                            validation_data=(x_val9, y_val9))

# MAE, R^2 Score
r2 = r2_score(y_cluster9_test, model_nn9.predict(x_cluster9_test))
mae = mean_absolute_error(y_cluster9_test, model_nn9.predict(x_cluster9_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn9.predict(x_cluster9_test), columns=['Pred'])
y_test_new = y_cluster9_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_train10, x_val10, y_train10, y_val10 = train_test_split(
    x_ff10_train, y_ff10_train, test_size=0.2, random_state=42)

model_nn10 = Sequential([
    Dense(64, activation='relu', input_shape=(5,)),
    Dense(32, activation='relu'),
    Dense(1)  # 1 выходной нейрон для регрессии
])

model_nn10.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_nn10 = model_nn10.fit(x_train10, y_train10, epochs=150,
                            validation_data=(x_val10, y_val10))

# MAE, R^2 Score
r2 = r2_score(y_cluster10_test, model_nn10.predict(x_cluster10_test))
mae = mean_absolute_error(y_cluster10_test, model_nn10.predict(x_cluster10_test))

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R^2): {r2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(model_nn10.predict(x_cluster10_test), columns=['Pred'])
y_test_new = y_cluster10_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))


plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Ensemble Model 1 (RF)

# %%
x_knn1 = knn1.predict(x_ff1_train)
x_lstm1 = model_lstm1.predict(x_ff1_train)
x_rf1 = best_rf1.predict(x_ff1_train)
x_nn1 = model_nn1.predict(x_ff1_train)
x_gbr1 = best_gbr1.predict(x_ff1_train)
x_lgbm1 = best_lgbm1.predict(x_ff1_train)
x_mlp1 = model_mlp1.predict(x_ff1_train)
# x_svm1 = model_svm1.predict(x_ff1_train)

df_ens1 = pd.DataFrame(x_knn1, columns=['KNN'])
df_ens1['LSTM'] = x_lstm1
df_ens1['RF'] = x_rf1
df_ens1['NN'] = x_nn1
df_ens1['GBR'] = x_gbr1
df_ens1['LGBM'] = x_lgbm1
df_ens1['MLP'] = x_mlp1
# df_ens1['SVM'] = x_svm
y_ff1_train_new = y_ff1_train.reset_index(drop=True)
df_ens1['value'] = y_ff1_train_new

x_ens1 = df_ens1.drop(['value'], axis=1)
y_ens1 = df_ens1['value']

scaler1 = StandardScaler()
scaler1.fit(x_ens1)

x_train1 = scaler1.transform(x_ens1)

model_ens_square1 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search_ens1 = GridSearchCV(estimator=model_ens_square1,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search_ens1.fit(x_train1, y_ens1)


best_params_ens1 = grid_search_ens1.best_params_
best_score_ens1 = np.sqrt(-grid_search_ens1.best_score_)  # 음수 MSE를 양수 변환 후 RMSE
print(f"Лучшие параметры: {best_params_ens1}")
print(f"Лучшая RMSE на обучающих данных: {best_score_ens1}")


# 테스트 데이터에 대한 예측
best_ens1 = grid_search_ens1.best_estimator_

df_for_checking1 = pd.DataFrame(knn1.predict(x_cluster1_test), columns=['KNN'])
df_for_checking1['LSTM'] = model_lstm1.predict(x_cluster1_test)
df_for_checking1['RF'] = best_rf1.predict(x_cluster1_test)
df_for_checking1['NN'] = model_nn1.predict(x_cluster1_test)
df_for_checking1['GBR'] = best_gbr1.predict(x_cluster1_test)
df_for_checking1['LGBM'] = best_lgbm1.predict(x_cluster1_test)
df_for_checking1['MLP'] = model_mlp1.predict(x_cluster1_test)

x_for_checking1 = scaler1.transform(df_for_checking1)

predict_ens1 = best_ens1.predict(x_for_checking1)

r2_ensemble1 = r2_score(y_cluster1_test, predict_ens1)
mae_ensemble1 = mean_absolute_error(y_cluster1_test, predict_ens1)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble1:.2f}")
print(f"R-squared (R^2): {r2_ensemble1:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_ens1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_knn2 = knn2.predict(x_ff2_train)
x_lstm2 = model_lstm2.predict(x_ff2_train)
x_rf2 = best_rf2.predict(x_ff2_train)
x_nn2 = model_nn2.predict(x_ff2_train)
x_gbr2 = best_gbr2.predict(x_ff2_train)
x_lgbm2 = best_lgbm2.predict(x_ff2_train)
x_mlp2 = model_mlp2.predict(x_ff2_train)
# x_svm2 = model_svm2.predict(x_ff2_train)

df_ens2 = pd.DataFrame(x_knn2, columns=['KNN'])
df_ens2['LSTM'] = x_lstm2
df_ens2['RF'] = x_rf2
df_ens2['NN'] = x_nn2
df_ens2['GBR'] = x_gbr2
df_ens2['LGBM'] = x_lgbm2
df_ens2['MLP'] = x_mlp2
# df_ens2['SVM'] = x_svm2
y_ff2_train_new = y_ff2_train.reset_index(drop=True)
df_ens2['value'] = y_ff2_train_new

x_ens2 = df_ens2.drop(['value'], axis=1)
y_ens2 = df_ens2['value']

scaler2 = StandardScaler()
scaler2.fit(x_ens2)

x_train2 = scaler2.transform(x_ens2)

model_ens_square2 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}

grid_search_ens2 = GridSearchCV(estimator=model_ens_square2,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search_ens2.fit(x_train2, y_ens2)


best_params_ens2 = grid_search_ens2.best_params_
best_score_ens2 = np.sqrt(-grid_search_ens2.best_score_)  # 음수 MSE를 양수 변환 후 RMSE
print(f"Лучшие параметры: {best_params_ens2}")
print(f"Лучшая RMSE на обучающих данных: {best_score_ens2}")


# 테스트 데이터에 대한 예측
best_ens2 = grid_search_ens2.best_estimator_

df_for_checking2 = pd.DataFrame(knn2.predict(x_cluster2_test), columns=['KNN'])
df_for_checking2['LSTM'] = model_lstm2.predict(x_cluster2_test)
df_for_checking2['RF'] = best_rf2.predict(x_cluster2_test)
df_for_checking2['NN'] = model_nn2.predict(x_cluster2_test)
df_for_checking2['GBR'] = best_gbr2.predict(x_cluster2_test)
df_for_checking2['LGBM'] = best_lgbm2.predict(x_cluster2_test)
df_for_checking2['MLP'] = model_mlp2.predict(x_cluster2_test)

x_for_checking2 = scaler2.transform(df_for_checking2)

predict_ens2 = best_ens2.predict(x_for_checking2)

r2_ensemble2 = r2_score(y_cluster2_test, predict_ens2)
mae_ensemble2 = mean_absolute_error(y_cluster2_test, predict_ens2)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble2:.2f}")
print(f"R-squared (R^2): {r2_ensemble2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_ens2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_knn3 = knn3.predict(x_ff3_train)
x_lstm3 = model_lstm3.predict(x_ff3_train)
x_rf3 = best_rf3.predict(x_ff3_train)
x_nn3 = model_nn3.predict(x_ff3_train)
x_gbr3 = best_gbr3.predict(x_ff3_train)
x_lgbm3 = best_lgbm3.predict(x_ff3_train)
x_mlp3 = model_mlp3.predict(x_ff3_train)
# x_svm1 = model_svm1.predict(x_ff1_train)

df_ens3 = pd.DataFrame(x_knn3, columns=['KNN'])
df_ens3['LSTM'] = x_lstm3
df_ens3['RF'] = x_rf3
df_ens3['NN'] = x_nn3
df_ens3['GBR'] = x_gbr3
df_ens3['LGBM'] = x_lgbm3
df_ens3['MLP'] = x_mlp3
# df_ens1['SVM'] = x_svm
y_ff3_train_new = y_ff3_train.reset_index(drop=True)
df_ens3['value'] = y_ff3_train_new

x_ens3 = df_ens3.drop(['value'], axis=1)
y_ens3 = df_ens3['value']

scaler3 = StandardScaler()
scaler3.fit(x_ens3)

x_train3 = scaler3.transform(x_ens3)

model_ens_square3 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}


grid_search_ens3 = GridSearchCV(estimator=model_ens_square3,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search_ens3.fit(x_train3, y_ens3)


best_params_ens3 = grid_search_ens3.best_params_
best_score_ens3 = np.sqrt(-grid_search_ens3.best_score_) # MAE, R^2 Score
print(f"Лучшие параметры: {best_params_ens3}")
print(f"Лучшая RMSE на обучающих данных: {best_score_ens3}")


# 테스트 데이터에 대한 예측
best_ens3 = grid_search_ens3.best_estimator_

df_for_checking3 = pd.DataFrame(knn3.predict(x_cluster3_test), columns=['KNN'])
df_for_checking3['LSTM'] = model_lstm3.predict(x_cluster3_test)
df_for_checking3['RF'] = best_rf3.predict(x_cluster3_test)
df_for_checking3['NN'] = model_nn3.predict(x_cluster3_test)
df_for_checking3['GBR'] = best_gbr3.predict(x_cluster3_test)
df_for_checking3['LGBM'] = best_lgbm3.predict(x_cluster3_test)
df_for_checking3['MLP'] = model_mlp3.predict(x_cluster3_test)

x_for_checking3 = scaler3.transform(df_for_checking3)

predict_ens3 = best_ens3.predict(x_for_checking3)

r2_ensemble3 = r2_score(y_cluster3_test, predict_ens3)
mae_ensemble3 = mean_absolute_error(y_cluster3_test, predict_ens3)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble3:.2f}")
print(f"R-squared (R^2): {r2_ensemble3:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_ens3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_knn4 = knn4.predict(x_ff4_train)
x_lstm4 = model_lstm4.predict(x_ff4_train)
x_rf4 = best_rf4.predict(x_ff4_train)
x_nn4 = model_nn4.predict(x_ff4_train)
x_gbr4 = best_gbr4.predict(x_ff4_train)
x_lgbm4 = best_lgbm4.predict(x_ff4_train)
x_mlp4 = model_mlp4.predict(x_ff4_train)
# x_svm4 = model_svm4.predict(x_ff4_train)

df_ens4 = pd.DataFrame(x_knn4, columns=['KNN'])
df_ens4['LSTM'] = x_lstm4
df_ens4['RF'] = x_rf4
df_ens4['NN'] = x_nn4
df_ens4['GBR'] = x_gbr4
df_ens4['LGBM'] = x_lgbm4
df_ens4['MLP'] = x_mlp4
# df_ens1['SVM'] = x_svm
y_ff4_train_new = y_ff4_train.reset_index(drop=True)
df_ens4['value'] = y_ff4_train_new

x_ens4 = df_ens4.drop(['value'], axis=1)
y_ens4 = df_ens4['value']

scaler4 = StandardScaler()
scaler4.fit(x_ens4)

x_train4 = scaler4.transform(x_ens4)

model_ens_square4 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}


grid_search_ens4 = GridSearchCV(estimator=model_ens_square4,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search_ens4.fit(x_train4, y_ens4)


best_params_ens4 = grid_search_ens4.best_params_
best_score_ens4 = np.sqrt(-grid_search_ens4.best_score_)  # MAE, R^2 Score
print(f"Лучшие параметры: {best_params_ens4}")
print(f"Лучшая RMSE на обучающих данных: {best_score_ens4}")


# 테스트 데이터에 대한 예측
best_ens4 = grid_search_ens4.best_estimator_

df_for_checking4 = pd.DataFrame(knn4.predict(x_cluster4_test), columns=['KNN'])
df_for_checking4['LSTM'] = model_lstm4.predict(x_cluster4_test)
df_for_checking4['RF'] = best_rf4.predict(x_cluster4_test)
df_for_checking4['NN'] = model_nn4.predict(x_cluster4_test)
df_for_checking4['GBR'] = best_gbr4.predict(x_cluster4_test)
df_for_checking4['LGBM'] = best_lgbm4.predict(x_cluster4_test)
df_for_checking4['MLP'] = model_mlp4.predict(x_cluster4_test)

x_for_checking4 = scaler4.transform(df_for_checking4)

predict_ens4 = best_ens4.predict(x_for_checking4)

r2_ensemble4 = r2_score(y_cluster4_test, predict_ens4)
mae_ensemble4 = mean_absolute_error(y_cluster4_test, predict_ens4)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble4:.2f}")
print(f"R-squared (R^2): {r2_ensemble4:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_ens4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_knn5 = knn5.predict(x_ff5_train)
x_lstm5 = model_lstm5.predict(x_ff5_train)
x_rf5 = best_rf5.predict(x_ff5_train)
x_nn5 = model_nn5.predict(x_ff5_train)
x_gbr5 = best_gbr5.predict(x_ff5_train)
x_lgbm5 = best_lgbm5.predict(x_ff5_train)
x_mlp5 = model_mlp5.predict(x_ff5_train)
# x_svm4 = model_svm4.predict(x_ff4_train)

df_ens5 = pd.DataFrame(x_knn5, columns=['KNN'])
df_ens5['LSTM'] = x_lstm5
df_ens5['RF'] = x_rf5
df_ens5['NN'] = x_nn5
df_ens5['GBR'] = x_gbr5
df_ens5['LGBM'] = x_lgbm5
df_ens5['MLP'] = x_mlp5
# df_ens1['SVM'] = x_svm
y_ff5_train_new = y_ff5_train.reset_index(drop=True)
df_ens5['value'] = y_ff5_train_new

x_ens5 = df_ens5.drop(['value'], axis=1)
y_ens5 = df_ens5['value']

scaler5 = StandardScaler()
scaler5.fit(x_ens5)

x_train5 = scaler5.transform(x_ens5)

model_ens_square5 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}


grid_search_ens5 = GridSearchCV(estimator=model_ens_square5,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search_ens5.fit(x_train5, y_ens5)


best_params_ens5 = grid_search_ens5.best_params_
best_score_ens5 = np.sqrt(-grid_search_ens5.best_score_)  # 음수 MSE를 양수 변환 후 RMSE
print(f"Лучшие параметры: {best_params_ens5}")
print(f"Лучшая RMSE на обучающих данных: {best_score_ens5}")


# 테스트 데이터에 대한 예측
best_ens5 = grid_search_ens5.best_estimator_

df_for_checking5 = pd.DataFrame(knn5.predict(x_cluster5_test), columns=['KNN'])
df_for_checking5['LSTM'] = model_lstm5.predict(x_cluster5_test)
df_for_checking5['RF'] = best_rf5.predict(x_cluster5_test)
df_for_checking5['NN'] = model_nn5.predict(x_cluster5_test)
df_for_checking5['GBR'] = best_gbr5.predict(x_cluster5_test)
df_for_checking5['LGBM'] = best_lgbm5.predict(x_cluster5_test)
df_for_checking5['MLP'] = model_mlp5.predict(x_cluster5_test)

x_for_checking5 = scaler5.transform(df_for_checking5)

predict_ens5 = best_ens5.predict(x_for_checking5)

r2_ensemble5 = r2_score(y_cluster5_test, predict_ens5)
mae_ensemble5 = mean_absolute_error(y_cluster5_test, predict_ens5)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble5:.2f}")
print(f"R-squared (R^2): {r2_ensemble5:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_ens5, columns=['Pred'])
y_test_new = y_cluster5_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_knn6 = knn6.predict(x_ff6_train)
x_lstm6 = model_lstm6.predict(x_ff6_train)
x_rf6 = best_rf6.predict(x_ff6_train)
x_nn6 = model_nn6.predict(x_ff6_train)
x_gbr6 = best_gbr6.predict(x_ff6_train)
x_lgbm6 = best_lgbm6.predict(x_ff6_train)
x_mlp6 = model_mlp6.predict(x_ff6_train)
# x_svm4 = model_svm4.predict(x_ff4_train)

df_ens6 = pd.DataFrame(x_knn6, columns=['KNN'])
df_ens6['LSTM'] = x_lstm6
df_ens6['RF'] = x_rf6
df_ens6['NN'] = x_nn6
df_ens6['GBR'] = x_gbr6
df_ens6['LGBM'] = x_lgbm6
df_ens6['MLP'] = x_mlp6
# df_ens1['SVM'] = x_svm
y_ff6_train_new = y_ff6_train.reset_index(drop=True)
df_ens6['value'] = y_ff6_train_new

x_ens6 = df_ens6.drop(['value'], axis=1)
y_ens6 = df_ens6['value']

scaler6 = StandardScaler()
scaler6.fit(x_ens6)

x_train6 = scaler6.transform(x_ens6)

model_ens_square6 = RandomForestRegressor(random_state=42, verbose=1)

param_grid = {
    'n_estimators': [200],  # 트리 개수
    'max_depth': [10],  # 트리 최대 깊이
    'min_samples_split': [10],  # 분할을 위한 최소 샘플 수
    'min_samples_leaf': [1],  # 최소 샘플 수
    'max_features': ['auto'],  # 분할 시 고려할 특성
    'bootstrap': [True]  # bootstrap(재표본추출) 사용
}


grid_search_ens6 = GridSearchCV(estimator=model_ens_square6,
                           param_grid=param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           verbose=1, n_jobs=-1)

grid_search_ens6.fit(x_train6, y_ens6)


best_params_ens6 = grid_search_ens6.best_params_
best_score_ens6 = np.sqrt(-grid_search_ens6.best_score_)  # 음수 MSE를 양수 변환 후 RMSE
print(f"Лучшие параметры: {best_params_ens6}")
print(f"Лучшая RMSE на обучающих данных: {best_score_ens6}")


# 테스트 데이터에 대한 예측
best_ens6 = grid_search_ens6.best_estimator_

df_for_checking6 = pd.DataFrame(knn6.predict(x_cluster6_test), columns=['KNN'])
df_for_checking6['LSTM'] = model_lstm6.predict(x_cluster6_test)
df_for_checking6['RF'] = best_rf6.predict(x_cluster6_test)
df_for_checking6['NN'] = model_nn6.predict(x_cluster6_test)
df_for_checking6['GBR'] = best_gbr6.predict(x_cluster6_test)
df_for_checking6['LGBM'] = best_lgbm6.predict(x_cluster6_test)
df_for_checking6['MLP'] = model_mlp6.predict(x_cluster6_test)

x_for_checking6 = scaler6.transform(df_for_checking6)

predict_ens6 = best_ens6.predict(x_for_checking6)

r2_ensemble6 = r2_score(y_cluster6_test, predict_ens6)
mae_ensemble6 = mean_absolute_error(y_cluster6_test, predict_ens6)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble6:.2f}")
print(f"R-squared (R^2): {r2_ensemble6:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results = pd.DataFrame(predict_ens6, columns=['Pred'])
y_test_new = y_cluster6_test.reset_index(drop=True)
results['Test'] = y_test_new
print(results.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results['Test'], results['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Ensemble Model 2 (NN)

# %%
x_ens2_1 = df_ens1.drop(['value'], axis=1)
y_ens2_1 = df_ens1['value']

x_ens2_1_train, x_ens2_1_val, y_ens2_1_train, y_ens2_1_val = train_test_split(
  x_ens2_1, y_ens2_1, test_size=0.2, random_state=42)

scaler1 = StandardScaler()
scaler1.fit(x_ens2_1)

x_train2_1 = scaler1.transform(x_ens2_1_train)

model_ensemble_nn1 = Sequential([
    Dense(128, activation='relu', input_shape=(8,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model_ensemble_nn1.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_ensemble_nn1 = model_ensemble_nn1.fit(
    x_train2_1, y_ens2_1_train, epochs=150, validation_data=(x_ens2_1_val, y_ens2_1_val))

predict_ensemble2_1 = model_ensemble_nn1.predict(x_for_checking1)

r2_ensemble2_1 = r2_score(y_cluster1_test, predict_ensemble2_1)
mae_ensemble2_1 = mean_absolute_error(y_cluster1_test, predict_ensemble2_1)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble2_1:.2f}")
print(f"R-squared (R^2): {r2_ensemble2_1:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_ensemble2_1 = pd.DataFrame(predict_ensemble2_1, columns=['Pred'])
y_test_ensemble2_1 = y_cluster1_test.reset_index(drop=True)
results_ensemble2_1['Test'] = y_test_ensemble2_1
print(results_ensemble2_1.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_ensemble2_1['Test'], results_ensemble2_1['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_ens2_2 = df_ens2.drop(['value'], axis=1)
y_ens2_2 = df_ens2['value']

x_ens2_2_train, x_ens2_2_val, y_ens2_2_train, y_ens2_2_val = train_test_split(
  x_ens2_2, y_ens2_2, test_size=0.2, random_state=42)

scaler2 = StandardScaler()
scaler2.fit(x_ens2_2)

x_train2_2 = scaler2.transform(x_ens2_2_train)

model_ensemble_nn2 = Sequential([
    Dense(128, activation='relu', input_shape=(8,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model_ensemble_nn2.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_ensemble_nn2 = model_ensemble_nn2.fit(
    x_train2_2, y_ens2_2_train, epochs=150, validation_data=(x_ens2_2_val, y_ens2_2_val))

predict_ensemble2_2 = model_ensemble_nn2.predict(x_for_checking2)

r2_ensemble2_2 = r2_score(y_cluster2_test, predict_ensemble2_2)
mae_ensemble2_2 = mean_absolute_error(y_cluster2_test, predict_ensemble2_2)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble2_2:.2f}")
print(f"R-squared (R^2): {r2_ensemble2_2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_ensemble2_2 = pd.DataFrame(predict_ensemble2_2, columns=['Pred'])
y_test_ensemble2_2 = y_cluster2_test.reset_index(drop=True)
results_ensemble2_2['Test'] = y_test_ensemble2_2
print(results_ensemble2_2.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_ensemble2_2['Test'], results_ensemble2_2['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_ens2_3 = df_ens3.drop(['value'], axis=1)
y_ens2_3 = df_ens3['value']

x_ens2_3_train, x_ens2_3_val, y_ens2_3_train, y_ens2_3_val = train_test_split(
  x_ens2_3, y_ens2_3, test_size=0.2, random_state=42)

scaler3 = StandardScaler()
scaler3.fit(x_ens3)

x_train2_3 = scaler3.transform(x_ens2_3_train)

model_ensemble_nn3 = Sequential([
    Dense(128, activation='relu', input_shape=(8,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model_ensemble_nn3.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_ensemble_nn3 = model_ensemble_nn3.fit(
    x_train2_3, y_ens2_3_train, epochs=150, validation_data=(x_ens2_3_val, y_ens2_3_val))

predict_ensemble2_3 = model_ensemble_nn3.predict(x_for_checking3)

r2_ensemble2_3 = r2_score(y_cluster3_test, predict_ensemble2_3)
mae_ensemble2_3 = mean_absolute_error(y_cluster3_test, predict_ensemble2_3)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble2_3:.2f}")
print(f"R-squared (R^2): {r2_ensemble2_3:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_ensemble2_3 = pd.DataFrame(predict_ensemble2_3, columns=['Pred'])
y_test_ensemble2_3 = y_cluster3_test.reset_index(drop=True)
results_ensemble2_3['Test'] = y_test_ensemble2_3
print(results_ensemble2_3.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_ensemble2_3['Test'], results_ensemble2_3['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
x_ens2_4 = df_ens4.drop(['value'], axis=1)
y_ens2_4 = df_ens4['value']

x_ens2_4_train, x_ens2_4_val, y_ens2_4_train, y_ens2_4_val = train_test_split(
  x_ens2_4, y_ens2_4, test_size=0.2, random_state=42)

scaler4 = StandardScaler()
scaler4.fit(x_ens4)

x_train2_4 = scaler4.transform(x_ens2_4_train)

model_ensemble_nn4 = Sequential([
    Dense(128, activation='relu', input_shape=(8,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model_ensemble_nn4.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
history_ensemble_nn4 = model_ensemble_nn4.fit(
    x_train2_4, y_ens2_4_train, epochs=150, validation_data=(x_ens2_4_val, y_ens2_4_val))

predict_ensemble2_4 = model_ensemble_nn4.predict(x_for_checking4)

r2_ensemble2_4 = r2_score(y_cluster4_test, predict_ensemble2_4)
mae_ensemble2_4 = mean_absolute_error(y_cluster4_test, predict_ensemble2_4)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_ensemble2_4:.2f}")
print(f"R-squared (R^2): {r2_ensemble2_4:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_ensemble2_4 = pd.DataFrame(predict_ensemble2_4, columns=['Pred'])
y_test_ensemble2_4 = y_cluster4_test.reset_index(drop=True)
results_ensemble2_4['Test'] = y_test_ensemble2_4
print(results_ensemble2_4.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_ensemble2_4['Test'], results_ensemble2_4['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Ensemble Model 3 (Voting)

# %%
ensemble_voting1 = VotingRegressor(estimators=[
    ('RF', best_rf1),
    ('MLP', model_mlp1),
    ('KNN', knn1),
    ('GBR', best_gbr1),
    ('LGBM', best_lgbm1),
])

ensemble_voting4 = VotingRegressor(estimators=[
    ('RF', best_rf4),
    ('MLP', model_mlp4),
    ('KNN', knn2),
    ('GBR', best_gbr4),
    ('LGBM', best_lgbm4),
])

ensemble_voting3 = VotingRegressor(estimators=[
    ('RF', best_rf3),
    ('MLP', model_mlp3),
    ('KNN', knn3),
    ('GBR', best_gbr3),
    ('LGBM', best_lgbm3),
])


ensemble_voting2 = VotingRegressor(estimators=[
    ('RF', best_rf2),
    ('MLP', model_mlp2),
    ('KNN', knn2),
    ('GBR', best_gbr2),
    ('LGBM', best_lgbm2),
])

# %%
scaler1 = StandardScaler()
scaler4 = StandardScaler()
scaler3 = StandardScaler()
scaler2 = StandardScaler()

scaler1.fit(x_ff1_train)
scaler4.fit(x_ff4_train)
scaler3.fit(x_ff3_train)
scaler2.fit(x_ff2_train)

x_ff1_train = scaler1.transform(x_ff1_train)
x_ff4_train = scaler4.transform(x_ff4_train)
x_ff3_train = scaler3.transform(x_ff3_train)
x_ff2_train = scaler2.transform(x_ff2_train)

ensemble_voting1.fit(x_ff1_train, y_ff1_train)
ensemble_voting4.fit(x_ff4_train, y_ff4_train)
ensemble_voting3.fit(x_ff3_train, y_ff3_train)
ensemble_voting2.fit(x_ff2_train, y_ff2_train)

# %%
predict_voting1 = ensemble_voting1.predict(x_cluster1_test)
predict_voting4 = ensemble_voting4.predict(x_cluster4_test)
predict_voting3 = ensemble_voting3.predict(x_cluster3_test)
predict_voting2 = ensemble_voting2.predict(x_cluster2_test)

# %%
r2_voting1 = r2_score(y_cluster1_test, predict_voting1)
mae_voting1 = mean_absolute_error(y_cluster1_test, predict_voting1)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_voting1:.2f}")
print(f"R-squared (R^2): {r2_voting1:.2f}")

r2_voting4 = r2_score(y_cluster4_test, predict_voting4)
mae_voting4 = mean_absolute_error(y_cluster4_test, predict_voting4)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_voting4:.2f}")
print(f"R-squared (R^2): {r2_voting4:.2f}")

r2_voting3 = r2_score(y_cluster3_test, predict_voting3)
mae_voting3 = mean_absolute_error(y_cluster3_test, predict_voting3)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_voting3:.2f}")
print(f"R-squared (R^2): {r2_voting3:.2f}")

r2_voting2 = r2_score(y_cluster2_test, predict_voting2)
mae_voting2 = mean_absolute_error(y_cluster2_test, predict_voting2)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_voting2:.2f}")
print(f"R-squared (R^2): {r2_voting2:.2f}")

# %%
# 예측 데이터와 테스트 데이터의 비교
results_voting = pd.DataFrame(predict_voting1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results_voting['Test'] = y_test_new
print(results_voting.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_voting['Test'], results_voting['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# 예측 데이터와 테스트 데이터의 비교
results_voting = pd.DataFrame(predict_voting4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results_voting['Test'] = y_test_new
print(results_voting.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_voting['Test'], results_voting['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# 예측 데이터와 테스트 데이터의 비교
results_voting = pd.DataFrame(predict_voting3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results_voting['Test'] = y_test_new
print(results_voting.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_voting['Test'], results_voting['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
# 예측 데이터와 테스트 데이터의 비교
results_voting = pd.DataFrame(predict_voting2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results_voting['Test'] = y_test_new
print(results_voting.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_voting['Test'], results_voting['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %% [markdown]
# # Ensemble Model (Stacking)

# %%
meta_x_train1 = np.column_stack((
    knn1.predict(x_ff1_train),
    best_gbr1.predict(x_ff1_train),
    best_lgbm1.predict(x_ff1_train),
    model_lstm1.predict(x_ff1_train),
    model_mlp1.predict(x_ff1_train),
    model_nn1.predict(x_ff1_train),
    best_rf1.predict(x_ff1_train)))

meta_x_test1 = np.column_stack((
    knn1.predict(x_cluster1_test),
    best_gbr1.predict(x_cluster1_test),
    best_lgbm1.predict(x_cluster1_test),
    model_lstm1.predict(x_cluster1_test),
    model_mlp1.predict(x_cluster1_test),
    model_nn1.predict(x_cluster1_test),
    best_rf1.predict(x_cluster1_test)))

meta_model1_1 = LinearRegression()
meta_model1_1.fit(meta_x_train1, y_ff1_train)

meta_model2_1 = RandomForestRegressor(random_state=42, verbose=1)
meta_model2_1.fit(meta_x_train1, y_ff1_train)

stacked_predictions1_1 = meta_model1_1.predict(meta_x_test1)
stacked_predictions2_1 = meta_model2_1.predict(meta_x_test1)

r2_stacked1_1 = r2_score(y_cluster1_test, stacked_predictions1_1)
mae_stacked1_1 = mean_absolute_error(y_cluster1_test, stacked_predictions1_1)

r2_stacked2_1 = r2_score(y_cluster1_test, stacked_predictions2_1)
mae_stacked2_1 = mean_absolute_error(y_cluster1_test, stacked_predictions2_1)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked1_1:.2f}")
print(f"R-squared (R^2): {r2_stacked1_1:.2f}")

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked2_1:.2f}")
print(f"R-squared (R^2): {r2_stacked2_1:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_stacked1_1 = pd.DataFrame(stacked_predictions1_1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results_stacked1_1['Test'] = y_test_new
print(results_stacked1_1.head(50))

# 예측 데이터와 테스트 데이터의 비교
results_stacked2_1 = pd.DataFrame(stacked_predictions2_1, columns=['Pred'])
y_test_new = y_cluster1_test.reset_index(drop=True)
results_stacked2_1['Test'] = y_test_new
print(results_stacked2_1.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked1_1['Test'], results_stacked1_1['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked2_1['Test'], results_stacked2_1['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
meta_x_train3 = np.column_stack((
    knn3.predict(x_ff3_train),
    best_gbr3.predict(x_ff3_train),
    best_lgbm3.predict(x_ff3_train),
    model_lstm3.predict(x_ff3_train),
    model_mlp3.predict(x_ff3_train),
    model_nn3.predict(x_ff3_train),
    best_rf3.predict(x_ff3_train)))

meta_x_test3 = np.column_stack((
    knn3.predict(x_cluster3_test),
    best_gbr3.predict(x_cluster3_test),
    best_lgbm3.predict(x_cluster3_test),
    model_lstm3.predict(x_cluster3_test),
    model_mlp3.predict(x_cluster3_test),
    model_nn3.predict(x_cluster3_test),
    best_rf3.predict(x_cluster3_test)))

meta_model1_3 = LinearRegression()
meta_model1_3.fit(meta_x_train3, y_ff3_train)

meta_model2_3 = RandomForestRegressor(random_state=42, verbose=1)
meta_model2_3.fit(meta_x_train3, y_ff3_train)

stacked_predictions1_3 = meta_model1_3.predict(meta_x_test3)
stacked_predictions2_3 = meta_model2_3.predict(meta_x_test3)

r2_stacked1_3 = r2_score(y_cluster3_test, stacked_predictions1_3)
mae_stacked1_3 = mean_absolute_error(y_cluster3_test, stacked_predictions1_3)

r2_stacked2_3 = r2_score(y_cluster3_test, stacked_predictions2_3)
mae_stacked2_3 = mean_absolute_error(y_cluster3_test, stacked_predictions2_3)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked1_3:.2f}")
print(f"R-squared (R^2): {r2_stacked1_3:.2f}")

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked2_3:.2f}")
print(f"R-squared (R^2): {r2_stacked2_3:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_stacked1_3 = pd.DataFrame(stacked_predictions1_3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results_stacked1_3['Test'] = y_test_new
print(results_stacked1_3.head(50))

# 예측 데이터와 테스트 데이터의 비교
results_stacked2_3 = pd.DataFrame(stacked_predictions2_3, columns=['Pred'])
y_test_new = y_cluster3_test.reset_index(drop=True)
results_stacked2_3['Test'] = y_test_new
print(results_stacked2_3.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked1_3['Test'], results_stacked1_3['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked2_3['Test'], results_stacked2_3['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
meta_x_train4 = np.column_stack((
    knn4.predict(x_ff4_train),
    best_gbr4.predict(x_ff4_train),
    best_lgbm4.predict(x_ff4_train),
    model_lstm4.predict(x_ff4_train),
    model_mlp4predict(x_ff4_train),
    model_nn4.predict(x_ff4_train),
    best_rf4.predict(x_ff4_train)))

meta_x_test4 = np.column_stack((
    knn4.predict(x_cluster4_test),
    best_gbr4.predict(x_cluster4_test),
    best_lgbm4.predict(x_cluster4_test),
    model_lstm4.predict(x_cluster4_test),
    model_mlp4.predict(x_cluster4_test),
    model_nn4.predict(x_cluster4_test),
    best_rf4.predict(x_cluster4_test)))

meta_model1_4 = LinearRegression()
meta_model1_4.fit(meta_x_train4, y_ff4_train)

meta_model2_4 = RandomForestRegressor(random_state=42, verbose=1)
meta_model2_4.fit(meta_x_train4, y_ff4_train)

stacked_predictions1_4 = meta_model1_4.predict(meta_x_test4)
stacked_predictions2_4 = meta_model2_4.predict(meta_x_test4)

r2_stacked1_4 = r2_score(y_cluster4_test, stacked_predictions1_4)
mae_stacked1_4 = mean_absolute_error(y_cluster4_test, stacked_predictions1_4)

r2_stacked2_4 = r2_score(y_cluster4_test, stacked_predictions2_4)
mae_stacked2_4 = mean_absolute_error(y_cluster4_test, stacked_predictions2_4)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked1_4:.2f}")
print(f"R-squared (R^2): {r2_stacked1_4:.2f}")

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked2_4:.2f}")
print(f"R-squared (R^2): {r2_stacked2_4:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_stacked1_4 = pd.DataFrame(stacked_predictions1_4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results_stacked1_4['Test'] = y_test_new
print(results_stacked1_4.head(50))

# 예측 데이터와 테스트 데이터의 비교
results_stacked2_4 = pd.DataFrame(stacked_predictions2_4, columns=['Pred'])
y_test_new = y_cluster4_test.reset_index(drop=True)
results_stacked2_4['Test'] = y_test_new
print(results_stacked2_4.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked1_4['Test'], results_stacked1_4['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked2_4['Test'], results_stacked2_4['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

# %%
meta_x_train2 = np.column_stack((
    knn2.predict(x_ff2_train),
    best_gbr2.predict(x_ff2_train),
    best_lgbm2.predict(x_ff2_train),
    model_lstm2.predict(x_ff2_train),
    model_mlp2.predict(x_ff2_train),
    model_nn2.predict(x_ff2_train),
    best_rf2.predict(x_ff2_train)))

meta_x_test2 = np.column_stack((
    knn2.predict(x_cluster2_test),
    best_gbr2.predict(x_cluster2_test),
    best_lgbm2.predict(x_cluster2_test),
    model_lstm2.predict(x_cluster2_test),
    model_mlp2.predict(x_cluster2_test),
    model_nn2.predict(x_cluster2_test),
    best_rf2.predict(x_cluster2_test)))

meta_model1_2 = LinearRegression()
meta_model1_2.fit(meta_x_train2, y_ff2_train)

meta_model2_2 = RandomForestRegressor(random_state=42, verbose=1)
meta_model2_2.fit(meta_x_train2, y_ff2_train)

stacked_predictions1_2 = meta_model1_2.predict(meta_x_test2)
stacked_predictions2_2 = meta_model2_2.predict(meta_x_test2)

r2_stacked1_2 = r2_score(y_cluster2_test, stacked_predictions1_2)
mae_stacked1_2 = mean_absolute_error(y_cluster2_test, stacked_predictions1_2)

r2_stacked2_2 = r2_score(y_cluster2_test, stacked_predictions2_2)
mae_stacked2_2 = mean_absolute_error(y_cluster2_test, stacked_predictions2_2)

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked1_2:.2f}")
print(f"R-squared (R^2): {r2_stacked1_2:.2f}")

# MAE, R^2 Score
print(f"Mean Absolute Error (MAE): {mae_stacked2_2:.2f}")
print(f"R-squared (R^2): {r2_stacked2_2:.2f}")

# 예측 데이터와 테스트 데이터의 비교
results_stacked1_2 = pd.DataFrame(stacked_predictions1_2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results_stacked1_2['Test'] = y_test_new
print(results_stacked1_2.head(50))

# 예측 데이터와 테스트 데이터의 비교
results_stacked2_2 = pd.DataFrame(stacked_predictions2_2, columns=['Pred'])
y_test_new = y_cluster2_test.reset_index(drop=True)
results_stacked2_2['Test'] = y_test_new
print(results_stacked2_2.head(50))

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked1_2['Test'], results_stacked1_2['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.scatter(results_stacked2_2['Test'], results_stacked2_2['Pred'], label='Value')
plt.xlabel('Test')
plt.ylabel('Pred')
plt.legend('Test vs Pred')
plt.grid(True)
plt.show()
